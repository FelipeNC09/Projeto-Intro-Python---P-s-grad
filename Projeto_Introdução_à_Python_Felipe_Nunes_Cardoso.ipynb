# %% [markdown]
# <a href="https://colab.research.google.com/github/FelipeNC09/Projeto-Intro-Python---P-s-grad/blob/main/Projeto_Introdu%C3%A7%C3%A3o_%C3%A0_Python_Felipe_Nunes_Cardoso.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Projeto para disciplina "Introdução à Linguagem de Programação Python para Biocientistas"**
#
# ##UNESP - Faculdade de Ciências Farmacêuticas
#
# ###*Programa de Pós-Graduação em Ciências Farmacêuticas*
#
# ---
#
# **Discente:** Felipe Nunes Cardoso
#
# **Docente:** Marcel Otávio Cerri

# %% [markdown]
# ##**1. Introdução**

# %% [markdown]
# #### O presente projeto visa, por meio do uso da linguagem de programação Python, o desenvolvimento de modelos de gráficos cujas construções serão necessárias para compor minha tese. Tais gráficos correspondem à expressão visual de dados previamente obtidos pelo Laboratório de Bioquímica e Enzimologia Clínicas através de sistemas-modelo *in vitro* de glicação proteica e *in vivo* de obesidade/resistência à insulina. Dessa forma, foram utilizadas as bibliotecas Pandas, Matplotlib, NumPy e SciPy.

# %% [markdown]
# ##**2. Códigos para aplicações usando dados *in vitro***

# %% [markdown]
# ####O sistema-modelo *in vitro* de glicação proteica baseia-se na incubação de albumina sérica bovina (BSA) com metilglioxal (MG), um composto dicarbonílico que age como agente agressor, por 4 dias, na ausência ou presença de diferentes concentrações de uma amostra de interesse e de aminoguanidina (AG), substância que atua como controle positivo de proteção.
#
# ####Ao longo dessa incubação, há o monitoramento espectrofluorimétrico da geração de diferentes níveis de marcadores do estresse glico-oxidativo, como produtos finais de glicação avançada (AGEs, do inglês "*advanced glycation end products*"), ditirosina, *N*'-formilquinurenina e quinurenina.
#
# ####A seguir, serão utilizados os dados referentes a uma incubação cuja amostra avaliada foi o extrato hidroetanólico de folhas de *Cissus verticillata* (CvExt).

# %% [markdown]
# ###**2.1. Código para teste estatístico One-Way ANOVA**

# %% [markdown]
# ####A fim de atestar as diferenças existes entre os resultados (intensidades de fluorescência) associados a cada grupo experimental conduzido no sistema-modelo *in vitro* de glicação proteica, as bibliotecas Pandas e Scipy foram empregadas para a importação de dados contidos em planihas do Excel e a execução do teste estatístico One-Way ANOVA, respectivamente.
#
# ####Os grupos experimentais são considerados diferentes caso o valor-p seja menor que 0.05.
#
# ####A desiginação "Condição A" diz respeito aos grupos experimentais onde BSA foi incubada com CvExt ou AG na ausência de MG; enquanto que a "Condição B" refere-se aos grupos experimentais onde BSA foi incubada com CvExt ou AG na presença de MG.
#
# ####Apesar das comparações realizadas (somente dois grupos por análise) não serem as mais adequadas para proposta do teste estatístico em questão, o mesmo ainda se mostra funcional e garante uma diversidade quanto ao potencial explorado da biblioteca Scipy.

# %%
#Importação de bibliotecas
import pandas as pd
from scipy.stats import f_oneway

#Importação de dados excel - Condição A
df = pd.read_excel("Python - Planilhas Fluorescências MG.xlsx", sheet_name="AGEs", skiprows=1, nrows=5)
df_np = df.values

print(("CONDIÇÃO A"))
print(140*"_")

#Dados Condição A
#|Dia 0|
dia_0 = df_np[0]
D0_BSA = dia_0[1:4]
D0_BSA_MG = dia_0[4:7]
D0_BSA_AG = dia_0[7:10]
D0_BSA_E250 = dia_0[10:13]
D0_BSA_E125 = dia_0[13:16]
D0_BSA_E62 = dia_0[16:19]

print(f'Dia 0 - One way BSA vs. BSA + MG = {f_oneway(D0_BSA, D0_BSA_MG)}')
print(f'Dia 0 - One way BSA vs. BSA + AG = {f_oneway(D0_BSA, D0_BSA_AG)}')
print(f'Dia 0 - One way BSA vs. BSA + CvExt 250 μg/mL = {f_oneway(D0_BSA, D0_BSA_E250)}')
print(f'Dia 0 - One way BSA vs. BSA + CvExt 125 μg/mL = {f_oneway(D0_BSA, D0_BSA_E125)}')
print(f'Dia 0 - One way BSA vs. BSA + CvExt 62.5 μg/mL = {f_oneway(D0_BSA, D0_BSA_E62)}')
print(f'Dia 0 - One way BSA + MG vs. BSA + AG = {f_oneway(D0_BSA_MG, D0_BSA_AG)}')
print(f'Dia 0 - One way BSA + MG vs. BSA + CvExt 250 μg/mL = {f_oneway(D0_BSA_MG, D0_BSA_E250)}')
print(f'Dia 0 - One way BSA + MG vs. BSA + CvExt 125 μg/mL = {f_oneway(D0_BSA_MG, D0_BSA_E125)}')
print(f'Dia 0 - One way BSA + MG vs. BSA + CvExt 62.5 μg/mL = {f_oneway(D0_BSA_MG, D0_BSA_E62)}')
print(f'Dia 0 - One way BSA + AG vs. BSA + CvExt 250 μg/mL = {f_oneway(D0_BSA_AG, D0_BSA_E250)}')
print(f'Dia 0 - One way BSA + AG vs. BSA + CvExt 125 μg/mL = {f_oneway(D0_BSA_AG, D0_BSA_E125)}')
print(f'Dia 0 - One way BSA + AG vs. BSA + CvExt 62.5 μg/mL = {f_oneway(D0_BSA_AG, D0_BSA_E62)}')
print(f'Dia 0 - One way BSA + CvExt 250 μg/mL vs. BSA + CvExt 125 μg/mL = {f_oneway(D0_BSA_E250, D0_BSA_E125)}')
print(f'Dia 0 - One way BSA + CvExt 250 μg/mL vs. BSA + CvExt 62.5 μg/mL = {f_oneway(D0_BSA_E250, D0_BSA_E62)}')
print(f'Dia 0 - One way BSA + CvExt 125 μg/mL vs. BSA + CvExt 62.5 μg/mL = {f_oneway(D0_BSA_E125, D0_BSA_E62)}')

print((140*"_"))

#|Dia 1|
dia_1 = df_np[1]
D1_BSA = dia_1[1:4]
D1_BSA_MG = dia_1[4:7]
D1_BSA_AG = dia_1[7:10]
D1_BSA_E250 = dia_1[10:13]
D1_BSA_E125 = dia_1[13:16]
D1_BSA_E62 = dia_1[16:19]

print(f'Dia 1 - One way BSA vs. BSA + MG = {f_oneway(D1_BSA, D1_BSA_MG)}')
print(f'Dia 1 - One way BSA vs. BSA + AG = {f_oneway(D1_BSA, D1_BSA_AG)}')
print(f'Dia 1 - One way BSA vs. BSA + CvExt 250 μg/mL = {f_oneway(D1_BSA, D1_BSA_E250)}')
print(f'Dia 1 - One way BSA vs. BSA + CvExt 125 μg/mL = {f_oneway(D1_BSA, D1_BSA_E125)}')
print(f'Dia 1 - One way BSA vs. BSA + CvExt 62.5 μg/mL = {f_oneway(D1_BSA, D1_BSA_E62)}')
print(f'Dia 1 - One way BSA + MG vs. BSA + AG = {f_oneway(D1_BSA_MG, D1_BSA_AG)}')
print(f'Dia 1 - One way BSA + MG vs. BSA + CvExt 250 μg/mL = {f_oneway(D1_BSA_MG, D1_BSA_E250)}')
print(f'Dia 1 - One way BSA + MG vs. BSA + CvExt 125 μg/mL = {f_oneway(D1_BSA_MG, D1_BSA_E125)}')
print(f'Dia 1 - One way BSA + MG vs. BSA + CvExt 62.5 μg/mL = {f_oneway(D1_BSA_MG, D1_BSA_E62)}')
print(f'Dia 1 - One way BSA + AG vs. BSA + CvExt 250 μg/mL = {f_oneway(D1_BSA_AG, D1_BSA_E250)}')
print(f'Dia 1 - One way BSA + AG vs. BSA + CvExt 125 μg/mL = {f_oneway(D1_BSA_AG, D1_BSA_E125)}')
print(f'Dia 1 - One way BSA + AG vs. BSA + CvExt 62.5 μg/mL = {f_oneway(D1_BSA_AG, D1_BSA_E62)}')
print(f'Dia 1 - One way BSA + CvExt 250 μg/mL vs. BSA + CvExt 125 μg/mL = {f_oneway(D1_BSA_E250, D1_BSA_E125)}')
print(f'Dia 1 - One way BSA + CvExt 250 μg/mL vs. BSA + CvExt 62.5 μg/mL = {f_oneway(D1_BSA_E250, D1_BSA_E62)}')
print(f'Dia 1 - One way BSA + CvExt 125 μg/mL vs. BSA + CvExt 62.5 μg/mL = {f_oneway(D1_BSA_E125, D1_BSA_E62)}')

print(140*"_")

#|Dia 2|
dia_2 = df_np[2]
D2_BSA = dia_2[1:4]
D2_BSA_MG = dia_2[4:7]
D2_BSA_AG = dia_2[7:10]
D2_BSA_E250 = dia_2[10:13]
D2_BSA_E125 = dia_2[13:16]
D2_BSA_E62 = dia_2[16:19]

print(f'Dia 2 - One way BSA vs. BSA + MG = {f_oneway(D2_BSA, D2_BSA_MG)}')
print(f'Dia 2 - One way BSA vs. BSA + AG = {f_oneway(D2_BSA, D2_BSA_AG)}')
print(f'Dia 2 - One way BSA vs. BSA + CvExt 250 μg/mL = {f_oneway(D2_BSA, D2_BSA_E250)}')
print(f'Dia 2 - One way BSA vs. BSA + CvExt 125 μg/mL = {f_oneway(D2_BSA, D2_BSA_E125)}')
print(f'Dia 2 - One way BSA vs. BSA + CvExt 62.5 μg/mL = {f_oneway(D2_BSA, D2_BSA_E62)}')
print(f'Dia 2 - One way BSA + MG vs. BSA + AG = {f_oneway(D2_BSA_MG, D2_BSA_AG)}')
print(f'Dia 2 - One way BSA + MG vs. BSA + CvExt 250 μg/mL = {f_oneway(D2_BSA_MG, D2_BSA_E250)}')
print(f'Dia 2 - One way BSA + MG vs. BSA + CvExt 125 μg/mL = {f_oneway(D2_BSA_MG, D2_BSA_E125)}')
print(f'Dia 2 - One way BSA + MG vs. BSA + CvExt 62.5 μg/mL = {f_oneway(D2_BSA_MG, D2_BSA_E62)}')
print(f'Dia 2 - One way BSA + AG vs. BSA + CvExt 250 μg/mL = {f_oneway(D2_BSA_AG, D2_BSA_E250)}')
print(f'Dia 2 - One way BSA + AG vs. BSA + CvExt 125 μg/mL = {f_oneway(D2_BSA_AG, D2_BSA_E125)}')
print(f'Dia 2 - One way BSA + AG vs. BSA + CvExt 62.5 μg/mL = {f_oneway(D2_BSA_AG, D2_BSA_E62)}')
print(f'Dia 2 - One way BSA + CvExt 250 μg/mL vs. BSA + CvExt 125 μg/mL = {f_oneway(D2_BSA_E250, D2_BSA_E125)}')
print(f'Dia 2 - One way BSA + CvExt 250 μg/mL vs. BSA + CvExt 62.5 μg/mL = {f_oneway(D2_BSA_E250, D2_BSA_E62)}')
print(f'Dia 2 - One way BSA + CvExt 125 μg/mL vs. BSA + CvExt 62.5 μg/mL = {f_oneway(D2_BSA_E125, D2_BSA_E62)}')

print(140*"_")

#|Dia 4|
dia_4 = df_np[3]
D4_BSA = dia_4[1:4]
D4_BSA_MG = dia_4[4:7]
D4_BSA_AG = dia_4[7:10]
D4_BSA_E250 = dia_4[10:13]
D4_BSA_E125 = dia_4[13:16]
D4_BSA_E62 = dia_4[16:19]

print(f'Dia 4 - One way BSA vs. BSA + MG = {f_oneway(D4_BSA, D4_BSA_MG)}')
print(f'Dia 4 - One way BSA vs. BSA + AG = {f_oneway(D4_BSA, D4_BSA_AG)}')
print(f'Dia 4 - One way BSA vs. BSA + CvExt 250 μg/mL = {f_oneway(D4_BSA, D4_BSA_E250)}')
print(f'Dia 4 - One way BSA vs. BSA + CvExt 125 μg/mL = {f_oneway(D4_BSA, D4_BSA_E125)}')
print(f'Dia 4 - One way BSA vs. BSA + CvExt 62.5 μg/mL = {f_oneway(D4_BSA, D4_BSA_E62)}')
print(f'Dia 4 - One way BSA + MG vs. BSA + AG = {f_oneway(D4_BSA_MG, D4_BSA_AG)}')
print(f'Dia 4 - One way BSA + MG vs. BSA + CvExt 250 μg/mL = {f_oneway(D4_BSA_MG, D4_BSA_E250)}')
print(f'Dia 4 - One way BSA + MG vs. BSA + CvExt 125 μg/mL = {f_oneway(D4_BSA_MG, D4_BSA_E125)}')
print(f'Dia 4 - One way BSA + MG vs. BSA + CvExt 62.5 μg/mL = {f_oneway(D4_BSA_MG, D4_BSA_E62)}')
print(f'Dia 4 - One way BSA + AG vs. BSA + CvExt 250 μg/mL = {f_oneway(D4_BSA_AG, D4_BSA_E250)}')
print(f'Dia 4 - One way BSA + AG vs. BSA + CvExt 125 μg/mL = {f_oneway(D4_BSA_AG, D4_BSA_E125)}')
print(f'Dia 4 - One way BSA + AG vs. BSA + CvExt 62.5 μg/mL = {f_oneway(D4_BSA_AG, D4_BSA_E62)}')
print(f'Dia 4 - One way BSA + CvExt 250 μg/mL vs. BSA + CvExt 125 μg/mL = {f_oneway(D4_BSA_E250, D4_BSA_E125)}')
print(f'Dia 4 - One way BSA + CvExt 250 μg/mL vs. BSA + CvExt 62.5 μg/mL = {f_oneway(D4_BSA_E250, D4_BSA_E62)}')
print(f'Dia 4 - One way BSA + CvExt 125 μg/mL vs. BSA + CvExt 62.5 μg/mL = {f_oneway(D4_BSA_E125, D4_BSA_E62)}')

print(" ")
print(140*"=")
print(" ")
print(" ")

#----------------------------------------------------------

#Importação de dados excel - Condição B
mgdf = pd.read_excel("Python - Planilhas Fluorescências MG.xlsx", sheet_name="AGEs",  usecols="A:S", skiprows=8)
mgdf_np = mgdf.values

print(("CONDIÇÃO B"))

print((140*"_"))

#Dados Condição B
#|Dia 0|
mgdia_0 = mgdf_np[0]
D0_BSA = mgdia_0[1:4]
D0_BSA_MG = mgdia_0[4:7]
D0_BSA_MG_AG = mgdia_0[7:10]
D0_BSA_MG_E250 = mgdia_0[10:13]
D0_BSA_MG_E125 = mgdia_0[13:16]
D0_BSA_MG_E62 = mgdia_0[16:19]

print(f'Dia 0 - One way BSA vs. BSA + MG = {f_oneway(D0_BSA, D0_BSA_MG)}')
print(f'Dia 0 - One way BSA vs. BSA + MG + AG = {f_oneway(D0_BSA, D0_BSA_MG_AG)}')
print(f'Dia 0 - One way BSA vs. BSA + MG + CvExt 250 μg/mL = {f_oneway(D0_BSA, D0_BSA_MG_E250)}')
print(f'Dia 0 - One way BSA vs. BSA + MG + CvExt 125 μg/mL = {f_oneway(D0_BSA, D0_BSA_MG_E125)}')
print(f'Dia 0 - One way BSA vs. BSA + MG + CvExt 62.5 μg/mL = {f_oneway(D0_BSA, D0_BSA_MG_E62)}')
print(f'Dia 0 - One way BSA + MG vs. BSA + MG + AG = {f_oneway(D0_BSA_MG, D0_BSA_MG_AG)}')
print(f'Dia 0 - One way BSA + MG vs. BSA + MG + CvExt 250 μg/mL = {f_oneway(D0_BSA_MG, D0_BSA_MG_E250)}')
print(f'Dia 0 - One way BSA + MG vs. BSA + MG + CvExt 125 μg/mL = {f_oneway(D0_BSA_MG, D0_BSA_MG_E125)}')
print(f'Dia 0 - One way BSA + MG vs. BSA + MG + CvExt 62.5 μg/mL = {f_oneway(D0_BSA_MG, D0_BSA_MG_E62)}')
print(f'Dia 0 - One way BSA + MG +AG vs. BSA + MG + CvExt 250 μg/mL = {f_oneway(D0_BSA_MG_AG, D0_BSA_MG_E250)}')
print(f'Dia 0 - One way BSA + MG + AG vs. BSA + MG + CvExt 125 μg/mL = {f_oneway(D0_BSA_MG_AG, D0_BSA_MG_E125)}')
print(f'Dia 0 - One way BSA + MG + AG vs. BSA + MG + CvExt 62.5 μg/mL = {f_oneway(D0_BSA_MG_AG, D0_BSA_MG_E62)}')
print(f'Dia 0 - One way BSA + MG + CvExt 250 μg/mL vs. BSA + MG + CvExt 125 μg/mL = {f_oneway(D0_BSA_MG_E250, D0_BSA_MG_E125)}')
print(f'Dia 0 - One way BSA + MG + CvExt 250 μg/mL vs. BSA + MG + CvExt 62.5 μg/mL = {f_oneway(D0_BSA_MG_E250, D0_BSA_MG_E62)}')
print(f'Dia 0 - One way BSA + MG + CvExt 125 μg/mL vs. BSA + MG + CvExt 62.5 μg/mL = {f_oneway(D0_BSA_MG_E125, D0_BSA_MG_E62)}')

print((140*"_"))

#|Dia 1|
mgdia_1 = mgdf_np[1]
D1_BSA = mgdia_1[1:4]
D1_BSA_MG = mgdia_1[4:7]
D1_BSA_MG_AG = mgdia_1[7:10]
D1_BSA_MG_E250 = mgdia_1[10:13]
D1_BSA_MG_E125 = mgdia_1[13:16]
D1_BSA_MG_E62 = mgdia_1[16:19]

print(f'Dia 1 - One way BSA vs. BSA + MG = {f_oneway(D1_BSA, D1_BSA_MG)}')
print(f'Dia 1 - One way BSA vs. BSA + MG + AG = {f_oneway(D1_BSA, D1_BSA_MG_AG)}')
print(f'Dia 1 - One way BSA vs. BSA + MG + CvExt 250 μg/mL = {f_oneway(D1_BSA, D1_BSA_MG_E250)}')
print(f'Dia 1 - One way BSA vs. BSA + MG + CvExt 125 μg/mL = {f_oneway(D1_BSA, D1_BSA_MG_E125)}')
print(f'Dia 1 - One way BSA vs. BSA + MG + CvExt 62.5 μg/mL = {f_oneway(D1_BSA, D1_BSA_MG_E62)}')
print(f'Dia 1 - One way BSA + MG vs. BSA + MG + AG = {f_oneway(D1_BSA_MG, D1_BSA_MG_AG)}')
print(f'Dia 1 - One way BSA + MG vs. BSA + MG + CvExt 250 μg/mL = {f_oneway(D1_BSA_MG, D1_BSA_MG_E250)}')
print(f'Dia 1 - One way BSA + MG vs. BSA + MG + CvExt 125 μg/mL = {f_oneway(D1_BSA_MG, D1_BSA_MG_E125)}')
print(f'Dia 1 - One way BSA + MG vs. BSA + MG + CvExt 62.5 μg/mL = {f_oneway(D1_BSA_MG, D1_BSA_MG_E62)}')
print(f'Dia 1 - One way BSA + MG +AG vs. BSA + MG + CvExt 250 μg/mL = {f_oneway(D1_BSA_MG_AG, D1_BSA_MG_E250)}')
print(f'Dia 1 - One way BSA + MG + AG vs. BSA + MG + CvExt 125 μg/mL = {f_oneway(D1_BSA_MG_AG, D1_BSA_MG_E125)}')
print(f'Dia 1 - One way BSA + MG + AG vs. BSA + MG + CvExt 62.5 μg/mL = {f_oneway(D1_BSA_MG_AG, D1_BSA_MG_E62)}')
print(f'Dia 1 - One way BSA + MG + CvExt 250 μg/mL vs. BSA + MG + CvExt 125 μg/mL = {f_oneway(D1_BSA_MG_E250, D1_BSA_MG_E125)}')
print(f'Dia 1 - One way BSA + MG + CvExt 250 μg/mL vs. BSA + MG + CvExt 62.5 μg/mL = {f_oneway(D1_BSA_MG_E250, D1_BSA_MG_E62)}')
print(f'Dia 1 - One way BSA + MG + CvExt 125 μg/mL vs. BSA + MG + CvExt 62.5 μg/mL = {f_oneway(D1_BSA_MG_E125, D1_BSA_MG_E62)}')

print(140*"_")

#|Dia 2|
mgdia_2 = mgdf_np[2]
D2_BSA = mgdia_2[1:4]
D2_BSA_MG = mgdia_2[4:7]
D2_BSA_MG_AG = mgdia_2[7:10]
D2_BSA_MG_E250 = mgdia_2[10:13]
D2_BSA_MG_E125 = mgdia_2[13:16]
D2_BSA_MG_E62 = mgdia_2[16:19]

print(f'Dia 2 - One way BSA vs. BSA + MG = {f_oneway(D2_BSA, D2_BSA_MG)}')
print(f'Dia 2 - One way BSA vs. BSA + MG + AG = {f_oneway(D2_BSA, D2_BSA_MG_AG)}')
print(f'Dia 2 - One way BSA vs. BSA + MG + CvExt 250 μg/mL = {f_oneway(D2_BSA, D2_BSA_MG_E250)}')
print(f'Dia 2 - One way BSA vs. BSA + MG + CvExt 125 μg/mL = {f_oneway(D2_BSA, D2_BSA_MG_E125)}')
print(f'Dia 2 - One way BSA vs. BSA + MG + CvExt 62.5 μg/mL = {f_oneway(D2_BSA, D2_BSA_MG_E62)}')
print(f'Dia 2 - One way BSA + MG vs. BSA + MG + AG = {f_oneway(D2_BSA_MG, D2_BSA_MG_AG)}')
print(f'Dia 2 - One way BSA + MG vs. BSA + MG + CvExt 250 μg/mL = {f_oneway(D2_BSA_MG, D2_BSA_MG_E250)}')
print(f'Dia 2 - One way BSA + MG vs. BSA + MG + CvExt 125 μg/mL = {f_oneway(D2_BSA_MG, D2_BSA_MG_E125)}')
print(f'Dia 2 - One way BSA + MG vs. BSA + MG + CvExt 62.5 μg/mL = {f_oneway(D2_BSA_MG, D2_BSA_MG_E62)}')
print(f'Dia 2 - One way BSA + MG +AG vs. BSA + MG + CvExt 250 μg/mL = {f_oneway(D2_BSA_MG_AG, D2_BSA_MG_E250)}')
print(f'Dia 2 - One way BSA + MG + AG vs. BSA + MG + CvExt 125 μg/mL = {f_oneway(D2_BSA_MG_AG, D2_BSA_MG_E125)}')
print(f'Dia 2 - One way BSA + MG + AG vs. BSA + MG + CvExt 62.5 μg/mL = {f_oneway(D2_BSA_MG_AG, D2_BSA_MG_E62)}')
print(f'Dia 2 - One way BSA + MG + CvExt 250 μg/mL vs. BSA + MG + CvExt 125 μg/mL = {f_oneway(D2_BSA_MG_E250, D2_BSA_MG_E125)}')
print(f'Dia 2 - One way BSA + MG + CvExt 250 μg/mL vs. BSA + MG + CvExt 62.5 μg/mL = {f_oneway(D2_BSA_MG_E250, D2_BSA_MG_E62)}')
print(f'Dia 2 - One way BSA + MG + CvExt 125 μg/mL vs. BSA + MG + CvExt 62.5 μg/mL = {f_oneway(D2_BSA_MG_E125, D2_BSA_MG_E62)}')

print(140*"_")

#|Dia 4|
mgdia_4 = mgdf_np[3]
D4_BSA = mgdia_4[1:4]
D4_BSA_MG = mgdia_4[4:7]
D4_BSA_MG_AG = mgdia_4[7:10]
D4_BSA_MG_E250 = mgdia_4[10:13]
D4_BSA_MG_E125 = mgdia_4[13:16]
D4_BSA_MG_E62 = mgdia_4[16:19]

print(f'Dia 4 - One way BSA vs. BSA + MG = {f_oneway(D4_BSA, D4_BSA_MG)}')
print(f'Dia 4 - One way BSA vs. BSA + MG + AG = {f_oneway(D4_BSA, D4_BSA_MG_AG)}')
print(f'Dia 4 - One way BSA vs. BSA + MG + CvExt 250 μg/mL = {f_oneway(D4_BSA, D4_BSA_MG_E250)}')
print(f'Dia 4 - One way BSA vs. BSA + MG + CvExt 125 μg/mL = {f_oneway(D4_BSA, D4_BSA_MG_E125)}')
print(f'Dia 4 - One way BSA vs. BSA + MG + CvExt 62.5 μg/mL = {f_oneway(D4_BSA, D4_BSA_MG_E62)}')
print(f'Dia 4 - One way BSA + MG vs. BSA + MG + AG = {f_oneway(D4_BSA_MG, D4_BSA_MG_AG)}')
print(f'Dia 4 - One way BSA + MG vs. BSA + MG + CvExt 250 μg/mL = {f_oneway(D4_BSA_MG, D4_BSA_MG_E250)}')
print(f'Dia 4 - One way BSA + MG vs. BSA + MG + CvExt 125 μg/mL = {f_oneway(D4_BSA_MG, D4_BSA_MG_E125)}')
print(f'Dia 4 - One way BSA + MG vs. BSA + MG + CvExt 62.5 μg/mL = {f_oneway(D4_BSA_MG, D4_BSA_MG_E62)}')
print(f'Dia 4 - One way BSA + MG +AG vs. BSA + MG + CvExt 250 μg/mL = {f_oneway(D4_BSA_MG_AG, D4_BSA_MG_E250)}')
print(f'Dia 4 - One way BSA + MG + AG vs. BSA + MG + CvExt 125 μg/mL = {f_oneway(D4_BSA_MG_AG, D4_BSA_MG_E125)}')
print(f'Dia 4 - One way BSA + MG + AG vs. BSA + MG + CvExt 62.5 μg/mL = {f_oneway(D4_BSA_MG_AG, D4_BSA_MG_E62)}')
print(f'Dia 4 - One way BSA + MG + CvExt 250 μg/mL vs. BSA + MG + CvExt 125 μg/mL = {f_oneway(D4_BSA_MG_E250, D4_BSA_MG_E125)}')
print(f'Dia 4 - One way BSA + MG + CvExt 250 μg/mL vs. BSA + MG + CvExt 62.5 μg/mL = {f_oneway(D4_BSA_MG_E250, D4_BSA_MG_E62)}')
print(f'Dia 4 - One way BSA + MG + CvExt 125 μg/mL vs. BSA + MG + CvExt 62.5 μg/mL = {f_oneway(D4_BSA_MG_E125, D4_BSA_MG_E62)}')

# %% [markdown]
# ###**2.2. Código para construção de modelos de gráficos de intensidade de fluorêscencia de marcadores glico-oxidativos**

# %% [markdown]
# ####A partir do uso das bibliotecas Pandas, NumPy, SciPy e Matplotlib, bem como dos achados no item 2.1, abaixo constam as linhas de código que configuram a construção de gráficos de barras relativos aos dados presentes na primeira planilha do arquivo "*Python - Planilhas Fluorescências MG.xlsx*", referente aos AGEs.
#
# ####O código também é aplicável para construção de gráficos atrelados aos demais marcadores do estresse glico-oxidativo, desde que realizadas alterações nas seções:
# *   Importação de dados excel;
# *   Configurações do eixo y;
# *   Formatação complemento do gráfico;
# *   Letras indicando diferenças estatísticas.

# %%
#Importação de bibliotecas
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

#Importação de dados excel - Condição A
df = pd.read_excel("Python - Planilhas Fluorescências MG.xlsx", sheet_name="AGEs", skiprows=1, nrows=5)
df_np = df.values

#Variável x - Condições A e B
tempo = [item[0] for item in df_np]
tempo_indexes = np.arange(len(tempo))
width = 0.08

#Variáveis y - Condição A
BSA = [np.mean(item[1:4]) for item in df_np]
BSA_MG = [np.mean(item[4:7]) for item in df_np]
BSA_AG = [np.mean(item[7:10]) for item in df_np]
BSA_E250 = [np.mean(item[10:13]) for item in df_np]
BSA_E125 = [np.mean(item[13:16]) for item in df_np]
BSA_E62 = [np.mean(item[16:19]) for item in df_np]

#Erro padrão - Condição A
Erro_BSA = [stats.sem(item[1:4]) for item in df_np]
Erro_BSA_MG = [stats.sem(item[4:7]) for item in df_np]
Erro_BSA_AG = [stats.sem(item[7:10]) for item in df_np]
Erro_BSA_E250 = [stats.sem(item[10:13]) for item in df_np]
Erro_BSA_E125 = [stats.sem(item[13:16]) for item in df_np]
Erro_BSA_E62 = [stats.sem(item[16:19]) for item in df_np]

#Tipo/formato do gráfico - Condição A
plt.figure(figsize=(8,5), edgecolor='k')
plt.subplot(211)
plt.bar(tempo_indexes -4.5*width, BSA, yerr=Erro_BSA, capsize=2.2,width=width, color='w', edgecolor='k', linewidth=1.3, label="BSA")
plt.bar(tempo_indexes -2.75*width, BSA_MG, yerr=Erro_BSA_MG, capsize=2.2, width=width, color= 'r', edgecolor='k', linewidth=1.3, label="BSA + MG")
plt.bar(tempo_indexes -1*width, BSA_AG, yerr=Erro_BSA_AG, capsize=2.2, width=width, color= 'b', edgecolor='k', linewidth=1.3, label="BSA + AG")
plt.bar(tempo_indexes +0.75*width, BSA_E250, yerr=Erro_BSA_E250, capsize=2.2, width=width, color= 'darkgreen', edgecolor='k', linewidth=1.3, label="BSA + CvExt 250 μg/mL")
plt.bar(tempo_indexes +2.5*width, BSA_E125, yerr=Erro_BSA_E125, capsize=2.2, width=width, color= 'seagreen', edgecolor='k', linewidth=1.3, label="BSA + CvExt 125 μg/mL")
plt.bar(tempo_indexes +4.35*width, BSA_E62, yerr=Erro_BSA_E62, capsize=2.2, width=width, color= 'lime', edgecolor='k', linewidth=1.3, label="BSA + CvExt 62.5 μg/mL")

#Configurações da legenda - Condição A
plt.legend(prop={'weight':'bold'}, fontsize=10.5, frameon=False, loc='right', bbox_to_anchor=(1.42, 0.45))

#Configurações do eixo x - Condição A
plt.xlabel("Tempo de incubação (Dias)", labelpad=8, fontsize=11, fontweight='bold')
plt.xticks(ticks=tempo_indexes, label=tempo, fontsize=10, fontweight='bold')
plt.xticks([0,1,2,3],['0','1','2','4'])

#Configurações do eixo y - Condição A
plt.ylabel("Intensidade de fluorescência (U.A)", labelpad=12, fontsize=9, fontweight='bold')
plt.yticks([0,10000,20000,30000,40000,50000],['0','1 x 10^4','2 x 10^4','3 x 10^4', '4 x 10^4', '5 x 10^4'], fontsize=10, fontweight='bold')
plt.ylim(0,50000)

#Formatação complemento do gráfico - Condição A
plt.title("Condição A", pad=14, fontsize=16, fontstyle='italic', fontweight='bold', va='bottom')
plt.text(1.05, 55700, 12*"_", fontsize=16, fontstyle='italic', fontweight='bold')
plt.tick_params(which='major', length=5, width=1.5)
plt.rcParams['axes.linewidth'] = 1.5
plt.rcParams['axes.spines.right'] = False
plt.rcParams['axes.spines.top'] = False

#Letras indicando diferenças estatísticas - Condição A
#|Dia 0|
plt.text(-0.397, 6000, "a", fontsize=10.5, fontweight='bold')
plt.text(-0.255, 8320, "b", fontsize=10.5, fontweight='bold')
plt.text(-0.137, 5400, "ac", fontsize=10, fontweight='bold')
plt.text(0.020, 3900, "d", fontsize=10.5, fontweight='bold')
plt.text(0.135, 4200, "de", fontsize=10, fontweight='bold')
plt.text(0.285, 4800, "ce", fontsize=10, fontweight='bold')

#|Dia 1|
plt.text(0.606, 5880, "a", fontsize=10.5, fontweight='bold')
plt.text(0.74, 29600, "b", fontsize=10.5, fontweight='bold')
plt.text(0.878, 5760, "a", fontsize=10.5, fontweight='bold')
plt.text(1.025, 4700, "c", fontsize=10.5, fontweight='bold')
plt.text(1.14, 5250, "ac", fontsize=10, fontweight='bold')
plt.text(1.31, 5750, "a", fontsize=10.5, fontweight='bold')

#|Dia 2|
plt.text(1.60, 5750, "a", fontsize=10.5, fontweight='bold')
plt.text(1.74, 31860, "b", fontsize=10.5, fontweight='bold')
plt.text(1.86, 5460, "ac", fontsize=10, fontweight='bold')
plt.text(1.995, 5415, "ad", fontsize=10, fontweight='bold')
plt.text(2.135, 6090, "ae", fontsize=10, fontweight='bold')
plt.text(2.285, 5800, "ae", fontsize=10, fontweight='bold')

#|Dia 4|
plt.text(2.602, 6850, "a", fontsize=10.5, fontweight='bold')
plt.text(2.745, 34760, "b", fontsize=10.5, fontweight='bold')
plt.text(2.89, 5460, "c", fontsize=10.5, fontweight='bold')
plt.text(3.005, 5720, "ac", fontsize=10, fontweight='bold')
plt.text(3.165, 7200, "a", fontsize=10.5, fontweight='bold')
plt.text(3.31, 6850, "a", fontsize=10.5, fontweight='bold')

#----------------------------------------------------------

#Importação dados excel - Condição B
mgdf = pd.read_excel("Python - Planilhas Fluorescências MG.xlsx", sheet_name="AGEs", usecols="A:S", skiprows=8)
mgdf_np = mgdf.values

#Variáveis y - Condição B
BSA = [np.mean(item[1:4]) for item in mgdf_np]
BSA_MG = [np.mean(item[4:7]) for item in mgdf_np]
BSA_MG_AG = [np.mean(item[7:10]) for item in mgdf_np]
BSA_MG_E250 = [np.mean(item[10:13]) for item in mgdf_np]
BSA_MG_E125 = [np.mean(item[13:16]) for item in mgdf_np]
BSA_MG_E62 = [np.mean(item[16:19]) for item in mgdf_np]

#Erro padrão - Condição B
Erro_BSA = [stats.sem(item[1:4]) for item in mgdf_np]
Erro_BSA_MG = [stats.sem(item[4:7]) for item in mgdf_np]
Erro_BSA_MG_AG = [stats.sem(item[7:10]) for item in mgdf_np]
Erro_BSA_MG_E250 = [stats.sem(item[10:13]) for item in mgdf_np]
Erro_BSA_MG_E125 = [stats.sem(item[13:16]) for item in mgdf_np]
Erro_BSA_MG_E62 = [stats.sem(item[16:19]) for item in mgdf_np]

#Tipo/formato do gráfico - Condição B
plt.figure(figsize=(8,5), edgecolor='k')
plt.subplot(212)
plt.bar(tempo_indexes -4.5*width, BSA, yerr=Erro_BSA, capsize=2.2,width=width, color='w', edgecolor='k', linewidth=1.3, label="BSA")
plt.bar(tempo_indexes -2.75*width, BSA_MG, yerr=Erro_BSA_MG, capsize=2.2, width=width, color= 'r', edgecolor='k', linewidth=1.3, label="BSA + MG")
plt.bar(tempo_indexes -1*width, BSA_MG_AG, yerr=Erro_BSA_MG_AG, capsize=2.2, width=width, color= 'b', edgecolor='k', linewidth=1.3, label="BSA + MG + AG")
plt.bar(tempo_indexes +0.75*width, BSA_MG_E250, yerr=Erro_BSA_MG_E250, capsize=2.2, width=width, color= 'darkgreen', edgecolor='k', linewidth=1.3, label="BSA + MG + CvExt 250 μg/mL")
plt.bar(tempo_indexes +2.5*width, BSA_MG_E125, yerr=Erro_BSA_MG_E125, capsize=2.2, width=width, color= 'seagreen', edgecolor='k', linewidth=1.3, label="BSA + MG + CvExt 125 μg/mL")
plt.bar(tempo_indexes +4.35*width, BSA_MG_E62, yerr=Erro_BSA_MG_E62, capsize=2.2, width=width, color= 'lime', edgecolor='k', linewidth=1.3, label="BSA + MG + CvExt 62.5 μg/mL")

#Configurações da legenda - Condição B
plt.legend(prop={'weight':'bold'}, fontsize=10.5, frameon=False, loc='right', bbox_to_anchor=(1.5, 0.45))

#Configurações do eixo x - Condição B
plt.xlabel("Tempo de incubação (Dias)", labelpad=8, fontsize=11, fontweight='bold')
plt.xticks(ticks=tempo_indexes, label=tempo, fontsize=10, fontweight='bold')
plt.xticks([0,1,2,3],['0','1','2','4'])

#Configurações do eixo y - Condição B
plt.ylabel("Intensidade de fluorescência (U.A)", labelpad=12, fontsize=9, fontweight='bold')
plt.yticks([0,10000,20000,30000,40000,50000],['0','1 x 10^4','2 x 10^4','3 x 10^4', '4 x 10^4', '5 x 10^4'], fontsize=10, fontweight='bold')
plt.ylim(0,50000)

#Formatação complemento do gráfico - Condição B
plt.title(" ",  pad=25, fontsize=30)
plt.text(1.03, 56680, "Condição B", fontsize=16, fontstyle='italic', fontweight='bold')
plt.text(1.05, 55700, 12*"_", fontsize=16, fontstyle='italic', fontweight='bold')
plt.tick_params(which='major', length=5, width=1.5)
plt.rcParams['axes.linewidth'] = 1.5
plt.rcParams['axes.spines.right'] = False
plt.rcParams['axes.spines.top'] = False

#Letras indicando diferenças estatísticas - Condição B
#|Dia 0|
plt.text(-0.398, 6000, "a", fontsize=10.5, fontweight='bold')
plt.text(-0.255, 8320, "b", fontsize=10.5, fontweight='bold')
plt.text(-0.115, 3000, "c", fontsize=10.5, fontweight='bold')
plt.text(0.016, 4900, "d", fontsize=10.5, fontweight='bold')
plt.text(0.161, 6270, "a", fontsize=10.5, fontweight='bold')
plt.text(0.307, 6860, "e", fontsize=10.5, fontweight='bold')

#|Dia 1|
plt.text(0.605, 5790, "a", fontsize=10.5, fontweight='bold')
plt.text(0.74, 30000, "b", fontsize=10.5, fontweight='bold')
plt.text(0.885, 6960, "c", fontsize=10.5, fontweight='bold')
plt.text(1.02, 13500, "d", fontsize=10.5, fontweight='bold')
plt.text(1.16, 20550, "e", fontsize=10.5, fontweight='bold')
plt.text(1.325, 26260, "f", fontsize=10.5, fontweight='bold')

#|Dia 2|
plt.text(1.60, 5750, "a", fontsize=10.5, fontweight='bold')
plt.text(1.74, 31860, "b", fontsize=10.5, fontweight='bold')
plt.text(1.885, 7900, "c", fontsize=10.5, fontweight='bold')
plt.text(2.02, 18000, "d", fontsize=10.5, fontweight='bold')
plt.text(2.161, 26130, "e", fontsize=10.5, fontweight='bold')
plt.text(2.313, 32190, "b", fontsize=10.5, fontweight='bold')

#|Dia 4|
plt.text(2.602, 6850, "a", fontsize=10.5, fontweight='bold')
plt.text(2.745, 34760, "b", fontsize=10.5, fontweight='bold')
plt.text(2.888, 8360, "c", fontsize=10.5, fontweight='bold')
plt.text(3.027, 22850, "d", fontsize=10.5, fontweight='bold')
plt.text(3.165, 31100, "b", fontsize=10.5, fontweight='bold')
plt.text(3.315, 38800, "b", fontsize=10.5, fontweight='bold')

plt.show()

# %% [markdown]
# ##**3. Códigos para aplicações usando dados *in vivo***

# %% [markdown]
# ####O sistema-modelo *in vivo* de obesidade/resistência à insulina fundamenta-se na manutenção e monitoramento de camundongos durante 16 semanas, sendo esses alimentados com uma dieta controle (normolipídica e normoglicidica) denominada padrão (P) e a outra dieta hiperlipídica (HL).
#
# ####A partir da oitava semana, inicia-se a administração de tratamentos envolvendo amostras de interesse e metformina (substância que atua como controle positivo de proteção), em diferentes concentrações, de forma isolada e/ou combinada, sendo elas veículadas em iorgute natural.
#
# ####A seguir, serão utilizados os dados referentes ao ganho de peso corporal e à ingestão alimentar de camundongos submetidos tanto aos respectivos regimes alimentares, quanto a tratamentos com  extrato etanólico de própolis vermelha brasileira.

# %% [markdown]
# ###**3.1. Códigos para teste estatístico Teste t de Student**

# %% [markdown]
# ####Para a importação de dados contidos em planihas do Excel e a execução do teste estatístico Teste t de Student com o intuito de verificar as diferenças existes entre os parâmetros monitorados de cada grupo experimental, foram utilizadas as bibliotecas Pandas e Scipy, na devida ordem.
#
# ####Os grupos experimentais são considerados diferentes caso o valor-p seja menor que 0.05.

# %% [markdown]
# ####**3.1.1. Dados de ganho de peso semanal**

# %%
#Importação de bibliotecas
import pandas as pd
from scipy.stats import ttest_ind

#|Semana 0|
sem0_P = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="D", skiprows=1, nrows=15)
S0_P = pd.DataFrame.dropna(sem0_P)
sem0_PP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="D", skiprows=20, nrows=15)
S0_PP = pd.DataFrame.dropna(sem0_PP)
sem0_HL = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="D", skiprows=39, nrows=15)
S0_HL = pd.DataFrame.dropna(sem0_HL)
sem0_HI = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="D", skiprows=58, nrows=15)
S0_HI = pd.DataFrame.dropna(sem0_HI)
sem0_HP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="D", skiprows=77, nrows=15)
S0_HP = pd.DataFrame.dropna(sem0_HP)
sem0_HM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="D", skiprows=96, nrows=15)
S0_HM = pd.DataFrame.dropna(sem0_HM)
sem0_HPM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="D", skiprows=115, nrows=15)
S0_HPM = pd.DataFrame.dropna(sem0_HPM)

print(f'Semana 0 - Teste t P vs. PP = {ttest_ind(S0_P, S0_PP)}')
print(f'Semana 0 - Teste t P vs. HL = {ttest_ind(S0_P, S0_HL)}')
print(f'Semana 0 - Teste t P vs. HI = {ttest_ind(S0_P, S0_HI)}')
print(f'Semana 0 - Teste t P vs. HP = {ttest_ind(S0_P, S0_HP)}')
print(f'Semana 0 - Teste t P vs. HM = {ttest_ind(S0_P, S0_HM)}')
print(f'Semana 0 - Teste t P vs. HPM = {ttest_ind(S0_P, S0_HPM)}')
print(f'Semana 0 - Teste t PP vs. HL = {ttest_ind(S0_PP, S0_HL)}')
print(f'Semana 0 - Teste t PP vs. HI = {ttest_ind(S0_PP, S0_HI)}')
print(f'Semana 0 - Teste t PP vs. HP = {ttest_ind(S0_PP, S0_HP)}')
print(f'Semana 0 - Teste t PP vs. HM = {ttest_ind(S0_PP, S0_HM)}')
print(f'Semana 0 - Teste t PP vs. HPM = {ttest_ind(S0_PP, S0_HPM)}')
print(f'Semana 0 - Teste t HL vs. HI = {ttest_ind(S0_HL, S0_HI)}')
print(f'Semana 0 - Teste t HL vs. HP = {ttest_ind(S0_HL, S0_HP)}')
print(f'Semana 0 - Teste t HL vs. HM = {ttest_ind(S0_HL, S0_HM)}')
print(f'Semana 0 - Teste t HL vs. HPM = {ttest_ind(S0_HL, S0_HPM)}')
print(f'Semana 0 - Teste t HI vs. HP = {ttest_ind(S0_HI, S0_HP)}')
print(f'Semana 0 - Teste t HI vs. HM = {ttest_ind(S0_HI, S0_HM)}')
print(f'Semana 0 - Teste t HI vs. HPM = {ttest_ind(S0_HI, S0_HPM)}')
print(f'Semana 0 - Teste t HP vs. HM = {ttest_ind(S0_HP, S0_HM)}')
print(f'Semana 0 - Teste t HP vs. HPM = {ttest_ind(S0_HI, S0_HPM)}')
print(f'Semana 0 - Teste t HM vs. HPM = {ttest_ind(S0_HI, S0_HPM)}')

print((140*"_"))

#|Semana 1|
sem1_P = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="E", skiprows=1, nrows=15)
S1_P = pd.DataFrame.dropna(sem1_P)
sem1_PP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="E", skiprows=20, nrows=15)
S1_PP = pd.DataFrame.dropna(sem1_PP)
sem1_HL = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="E", skiprows=39, nrows=15)
S1_HL = pd.DataFrame.dropna(sem1_HL)
sem1_HI = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="E", skiprows=58, nrows=15)
S1_HI = pd.DataFrame.dropna(sem1_HI)
sem1_HP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="E", skiprows=77, nrows=15)
S1_HP = pd.DataFrame.dropna(sem1_HP)
sem1_HM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="E", skiprows=96, nrows=15)
S1_HM = pd.DataFrame.dropna(sem1_HM)
sem1_HPM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="E", skiprows=115, nrows=15)
S1_HPM = pd.DataFrame.dropna(sem1_HPM)

print(f'Semana 1 - Teste t P vs. PP = {ttest_ind(S1_P, S1_PP)}')
print(f'Semana 1 - Teste t P vs. HL = {ttest_ind(S1_P, S1_HL)}')
print(f'Semana 1 - Teste t P vs. HI = {ttest_ind(S1_P, S1_HI)}')
print(f'Semana 1 - Teste t P vs. HP = {ttest_ind(S1_P, S1_HP)}')
print(f'Semana 1 - Teste t P vs. HM = {ttest_ind(S1_P, S1_HM)}')
print(f'Semana 1 - Teste t P vs. HPM = {ttest_ind(S1_P, S1_HPM)}')
print(f'Semana 1 - Teste t PP vs. HL = {ttest_ind(S1_PP, S1_HL)}')
print(f'Semana 1 - Teste t PP vs. HI = {ttest_ind(S1_PP, S1_HI)}')
print(f'Semana 1 - Teste t PP vs. HP = {ttest_ind(S1_PP, S1_HP)}')
print(f'Semana 1 - Teste t PP vs. HM = {ttest_ind(S1_PP, S1_HM)}')
print(f'Semana 1 - Teste t PP vs. HPM = {ttest_ind(S1_PP, S1_HPM)}')
print(f'Semana 1 - Teste t HL vs. HI = {ttest_ind(S1_HL, S1_HI)}')
print(f'Semana 1 - Teste t HL vs. HP = {ttest_ind(S1_HL, S1_HP)}')
print(f'Semana 1 - Teste t HL vs. HM = {ttest_ind(S1_HL, S1_HM)}')
print(f'Semana 1 - Teste t HL vs. HPM = {ttest_ind(S1_HL, S1_HPM)}')
print(f'Semana 1 - Teste t HI vs. HP = {ttest_ind(S1_HI, S1_HP)}')
print(f'Semana 1 - Teste t HI vs. HM = {ttest_ind(S1_HI, S1_HM)}')
print(f'Semana 1 - Teste t HI vs. HPM = {ttest_ind(S1_HI, S1_HPM)}')
print(f'Semana 1 - Teste t HP vs. HM = {ttest_ind(S1_HP, S1_HM)}')
print(f'Semana 1 - Teste t HP vs. HPM = {ttest_ind(S1_HI, S1_HPM)}')
print(f'Semana 1 - Teste t HM vs. HPM = {ttest_ind(S1_HI, S1_HPM)}')

print((140*"_"))

#|Semana 2|
sem2_P = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="F", skiprows=1, nrows=15)
S2_P = pd.DataFrame.dropna(sem2_P)
sem2_PP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="F", skiprows=20, nrows=15)
S2_PP = pd.DataFrame.dropna(sem2_PP)
sem2_HL = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="F", skiprows=39, nrows=15)
S2_HL = pd.DataFrame.dropna(sem2_HL)
sem2_HI = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="F", skiprows=58, nrows=15)
S2_HI = pd.DataFrame.dropna(sem2_HI)
sem2_HP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="F", skiprows=77, nrows=15)
S2_HP = pd.DataFrame.dropna(sem2_HP)
sem2_HM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="F", skiprows=96, nrows=15)
S2_HM = pd.DataFrame.dropna(sem2_HM)
sem2_HPM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="F", skiprows=115, nrows=15)
S2_HPM = pd.DataFrame.dropna(sem2_HPM)

print(f'Semana 2 - Teste t P vs. PP = {ttest_ind(S2_P, S2_PP)}')
print(f'Semana 2 - Teste t P vs. HL = {ttest_ind(S2_P, S2_HL)}')
print(f'Semana 2 - Teste t P vs. HI = {ttest_ind(S2_P, S2_HI)}')
print(f'Semana 2 - Teste t P vs. HP = {ttest_ind(S2_P, S2_HP)}')
print(f'Semana 2 - Teste t P vs. HM = {ttest_ind(S2_P, S2_HM)}')
print(f'Semana 2 - Teste t P vs. HPM = {ttest_ind(S2_P, S2_HPM)}')
print(f'Semana 2 - Teste t PP vs. HL = {ttest_ind(S2_PP, S2_HL)}')
print(f'Semana 2 - Teste t PP vs. HI = {ttest_ind(S2_PP, S2_HI)}')
print(f'Semana 2 - Teste t PP vs. HP = {ttest_ind(S2_PP, S2_HP)}')
print(f'Semana 2 - Teste t PP vs. HM = {ttest_ind(S2_PP, S2_HM)}')
print(f'Semana 2 - Teste t PP vs. HPM = {ttest_ind(S2_PP, S2_HPM)}')
print(f'Semana 2 - Teste t HL vs. HI = {ttest_ind(S2_HL, S2_HI)}')
print(f'Semana 2 - Teste t HL vs. HP = {ttest_ind(S2_HL, S2_HP)}')
print(f'Semana 2 - Teste t HL vs. HM = {ttest_ind(S2_HL, S2_HM)}')
print(f'Semana 2 - Teste t HL vs. HPM = {ttest_ind(S2_HL, S2_HPM)}')
print(f'Semana 2 - Teste t HI vs. HP = {ttest_ind(S2_HI, S2_HP)}')
print(f'Semana 2 - Teste t HI vs. HM = {ttest_ind(S2_HI, S2_HM)}')
print(f'Semana 2 - Teste t HI vs. HPM = {ttest_ind(S2_HI, S2_HPM)}')
print(f'Semana 2 - Teste t HP vs. HM = {ttest_ind(S2_HP, S2_HM)}')
print(f'Semana 2 - Teste t HP vs. HPM = {ttest_ind(S2_HI, S2_HPM)}')
print(f'Semana 2 - Teste t HM vs. HPM = {ttest_ind(S2_HI, S2_HPM)}')

print((140*"_"))

#|Semana 3|
sem3_P = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="G", skiprows=1, nrows=15)
S3_P = pd.DataFrame.dropna(sem3_P)
sem3_PP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="G", skiprows=20, nrows=15)
S3_PP = pd.DataFrame.dropna(sem3_PP)
sem3_HL = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="G", skiprows=39, nrows=15)
S3_HL = pd.DataFrame.dropna(sem3_HL)
sem3_HI = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="G", skiprows=58, nrows=15)
S3_HI = pd.DataFrame.dropna(sem3_HI)
sem3_HP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="G", skiprows=77, nrows=15)
S3_HP = pd.DataFrame.dropna(sem3_HP)
sem3_HM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="G", skiprows=96, nrows=15)
S3_HM = pd.DataFrame.dropna(sem3_HM)
sem3_HPM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="G", skiprows=115, nrows=15)
S3_HPM = pd.DataFrame.dropna(sem3_HPM)

print(f'Semana 3 - Teste t P vs. PP = {ttest_ind(S3_P, S3_PP)}')
print(f'Semana 3 - Teste t P vs. HL = {ttest_ind(S3_P, S3_HL)}')
print(f'Semana 3 - Teste t P vs. HI = {ttest_ind(S3_P, S3_HI)}')
print(f'Semana 3 - Teste t P vs. HP = {ttest_ind(S3_P, S3_HP)}')
print(f'Semana 3 - Teste t P vs. HM = {ttest_ind(S3_P, S3_HM)}')
print(f'Semana 3 - Teste t P vs. HPM = {ttest_ind(S3_P, S3_HPM)}')
print(f'Semana 3 - Teste t PP vs. HL = {ttest_ind(S3_PP, S3_HL)}')
print(f'Semana 3 - Teste t PP vs. HI = {ttest_ind(S3_PP, S3_HI)}')
print(f'Semana 3 - Teste t PP vs. HP = {ttest_ind(S3_PP, S3_HP)}')
print(f'Semana 3 - Teste t PP vs. HM = {ttest_ind(S3_PP, S3_HM)}')
print(f'Semana 3 - Teste t PP vs. HPM = {ttest_ind(S3_PP, S3_HPM)}')
print(f'Semana 3 - Teste t HL vs. HI = {ttest_ind(S3_HL, S3_HI)}')
print(f'Semana 3 - Teste t HL vs. HP = {ttest_ind(S3_HL, S3_HP)}')
print(f'Semana 3 - Teste t HL vs. HM = {ttest_ind(S3_HL, S3_HM)}')
print(f'Semana 3 - Teste t HL vs. HPM = {ttest_ind(S3_HL, S3_HPM)}')
print(f'Semana 3 - Teste t HI vs. HP = {ttest_ind(S3_HI, S3_HP)}')
print(f'Semana 3 - Teste t HI vs. HM = {ttest_ind(S3_HI, S3_HM)}')
print(f'Semana 3 - Teste t HI vs. HPM = {ttest_ind(S3_HI, S3_HPM)}')
print(f'Semana 3 - Teste t HP vs. HM = {ttest_ind(S3_HP, S3_HM)}')
print(f'Semana 3 - Teste t HP vs. HPM = {ttest_ind(S3_HI, S3_HPM)}')
print(f'Semana 3 - Teste t HM vs. HPM = {ttest_ind(S3_HI, S3_HPM)}')

print((140*"_"))

#|Semana 4|
sem4_P = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="H", skiprows=1, nrows=15)
S4_P = pd.DataFrame.dropna(sem4_P)
sem4_PP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="H", skiprows=20, nrows=15)
S4_PP = pd.DataFrame.dropna(sem4_PP)
sem4_HL = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="H", skiprows=39, nrows=15)
S4_HL = pd.DataFrame.dropna(sem4_HL)
sem4_HI = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="H", skiprows=58, nrows=15)
S4_HI = pd.DataFrame.dropna(sem4_HI)
sem4_HP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="H", skiprows=77, nrows=15)
S4_HP = pd.DataFrame.dropna(sem4_HP)
sem4_HM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="H", skiprows=96, nrows=15)
S4_HM = pd.DataFrame.dropna(sem4_HM)
sem4_HPM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="H", skiprows=115, nrows=15)
S4_HPM = pd.DataFrame.dropna(sem4_HPM)

print(f'Semana 4 - Teste t P vs. PP = {ttest_ind(S4_P, S4_PP)}')
print(f'Semana 4 - Teste t P vs. HL = {ttest_ind(S4_P, S4_HL)}')
print(f'Semana 4 - Teste t P vs. HI = {ttest_ind(S4_P, S4_HI)}')
print(f'Semana 4 - Teste t P vs. HP = {ttest_ind(S4_P, S4_HP)}')
print(f'Semana 4 - Teste t P vs. HM = {ttest_ind(S4_P, S4_HM)}')
print(f'Semana 4 - Teste t P vs. HPM = {ttest_ind(S4_P, S4_HPM)}')
print(f'Semana 4 - Teste t PP vs. HL = {ttest_ind(S4_PP, S4_HL)}')
print(f'Semana 4 - Teste t PP vs. HI = {ttest_ind(S4_PP, S4_HI)}')
print(f'Semana 4 - Teste t PP vs. HP = {ttest_ind(S4_PP, S4_HP)}')
print(f'Semana 4 - Teste t PP vs. HM = {ttest_ind(S4_PP, S4_HM)}')
print(f'Semana 4 - Teste t PP vs. HPM = {ttest_ind(S4_PP, S4_HPM)}')
print(f'Semana 4 - Teste t HL vs. HI = {ttest_ind(S4_HL, S4_HI)}')
print(f'Semana 4 - Teste t HL vs. HP = {ttest_ind(S4_HL, S4_HP)}')
print(f'Semana 4 - Teste t HL vs. HM = {ttest_ind(S4_HL, S4_HM)}')
print(f'Semana 4 - Teste t HL vs. HPM = {ttest_ind(S4_HL, S4_HPM)}')
print(f'Semana 4 - Teste t HI vs. HP = {ttest_ind(S4_HI, S4_HP)}')
print(f'Semana 4 - Teste t HI vs. HM = {ttest_ind(S4_HI, S4_HM)}')
print(f'Semana 4 - Teste t HI vs. HPM = {ttest_ind(S4_HI, S4_HPM)}')
print(f'Semana 4 - Teste t HP vs. HM = {ttest_ind(S4_HP, S4_HM)}')
print(f'Semana 4 - Teste t HP vs. HPM = {ttest_ind(S4_HI, S4_HPM)}')
print(f'Semana 4 - Teste t HM vs. HPM = {ttest_ind(S4_HI, S4_HPM)}')

print((140*"_"))

#|Semana 5|
sem5_P = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="I", skiprows=1, nrows=15)
S5_P = pd.DataFrame.dropna(sem5_P)
sem5_PP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="I", skiprows=20, nrows=15)
S5_PP = pd.DataFrame.dropna(sem5_PP)
sem5_HL = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="I", skiprows=39, nrows=15)
S5_HL = pd.DataFrame.dropna(sem5_HL)
sem5_HI = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="I", skiprows=58, nrows=15)
S5_HI = pd.DataFrame.dropna(sem5_HI)
sem5_HP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="I", skiprows=77, nrows=15)
S5_HP = pd.DataFrame.dropna(sem5_HP)
sem5_HM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="I", skiprows=96, nrows=15)
S5_HM = pd.DataFrame.dropna(sem5_HM)
sem5_HPM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="I", skiprows=115, nrows=15)
S5_HPM = pd.DataFrame.dropna(sem5_HPM)

print(f'Semana 5 - Teste t P vs. PP = {ttest_ind(S5_P, S5_PP)}')
print(f'Semana 5 - Teste t P vs. HL = {ttest_ind(S5_P, S5_HL)}')
print(f'Semana 5 - Teste t P vs. HI = {ttest_ind(S5_P, S5_HI)}')
print(f'Semana 5 - Teste t P vs. HP = {ttest_ind(S5_P, S5_HP)}')
print(f'Semana 5 - Teste t P vs. HM = {ttest_ind(S5_P, S5_HM)}')
print(f'Semana 5 - Teste t P vs. HPM = {ttest_ind(S5_P, S5_HPM)}')
print(f'Semana 5 - Teste t PP vs. HL = {ttest_ind(S5_PP, S5_HL)}')
print(f'Semana 5 - Teste t PP vs. HI = {ttest_ind(S5_PP, S5_HI)}')
print(f'Semana 5 - Teste t PP vs. HP = {ttest_ind(S5_PP, S5_HP)}')
print(f'Semana 5 - Teste t PP vs. HM = {ttest_ind(S5_PP, S5_HM)}')
print(f'Semana 5 - Teste t PP vs. HPM = {ttest_ind(S5_PP, S5_HPM)}')
print(f'Semana 5 - Teste t HL vs. HI = {ttest_ind(S5_HL, S5_HI)}')
print(f'Semana 5 - Teste t HL vs. HP = {ttest_ind(S5_HL, S5_HP)}')
print(f'Semana 5 - Teste t HL vs. HM = {ttest_ind(S5_HL, S5_HM)}')
print(f'Semana 5 - Teste t HL vs. HPM = {ttest_ind(S5_HL, S5_HPM)}')
print(f'Semana 5 - Teste t HI vs. HP = {ttest_ind(S5_HI, S5_HP)}')
print(f'Semana 5 - Teste t HI vs. HM = {ttest_ind(S5_HI, S5_HM)}')
print(f'Semana 5 - Teste t HI vs. HPM = {ttest_ind(S5_HI, S5_HPM)}')
print(f'Semana 5 - Teste t HP vs. HM = {ttest_ind(S5_HP, S5_HM)}')
print(f'Semana 5 - Teste t HP vs. HPM = {ttest_ind(S5_HI, S5_HPM)}')
print(f'Semana 5 - Teste t HM vs. HPM = {ttest_ind(S5_HI, S5_HPM)}')

print((140*"_"))

#|Semana 6|
sem6_P = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="J", skiprows=1, nrows=15)
S6_P = pd.DataFrame.dropna(sem6_P)
sem6_PP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="J", skiprows=20, nrows=15)
S6_PP = pd.DataFrame.dropna(sem6_PP)
sem6_HL = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="J", skiprows=39, nrows=15)
S6_HL = pd.DataFrame.dropna(sem6_HL)
sem6_HI = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="J", skiprows=58, nrows=15)
S6_HI = pd.DataFrame.dropna(sem6_HI)
sem6_HP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="J", skiprows=77, nrows=15)
S6_HP = pd.DataFrame.dropna(sem6_HP)
sem6_HM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="J", skiprows=96, nrows=15)
S6_HM = pd.DataFrame.dropna(sem6_HM)
sem6_HPM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="J", skiprows=115, nrows=15)
S6_HPM = pd.DataFrame.dropna(sem6_HPM)

print(f'Semana 6 - Teste t P vs. PP = {ttest_ind(S6_P, S6_PP)}')
print(f'Semana 6 - Teste t P vs. HL = {ttest_ind(S6_P, S6_HL)}')
print(f'Semana 6 - Teste t P vs. HI = {ttest_ind(S6_P, S6_HI)}')
print(f'Semana 6 - Teste t P vs. HP = {ttest_ind(S6_P, S6_HP)}')
print(f'Semana 6 - Teste t P vs. HM = {ttest_ind(S6_P, S6_HM)}')
print(f'Semana 6 - Teste t P vs. HPM = {ttest_ind(S6_P, S6_HPM)}')
print(f'Semana 6 - Teste t PP vs. HL = {ttest_ind(S6_PP, S6_HL)}')
print(f'Semana 6 - Teste t PP vs. HI = {ttest_ind(S6_PP, S6_HI)}')
print(f'Semana 6 - Teste t PP vs. HP = {ttest_ind(S6_PP, S6_HP)}')
print(f'Semana 6 - Teste t PP vs. HM = {ttest_ind(S6_PP, S6_HM)}')
print(f'Semana 6 - Teste t PP vs. HPM = {ttest_ind(S6_PP, S6_HPM)}')
print(f'Semana 6 - Teste t HL vs. HI = {ttest_ind(S6_HL, S6_HI)}')
print(f'Semana 6 - Teste t HL vs. HP = {ttest_ind(S6_HL, S6_HP)}')
print(f'Semana 6 - Teste t HL vs. HM = {ttest_ind(S6_HL, S6_HM)}')
print(f'Semana 6 - Teste t HL vs. HPM = {ttest_ind(S6_HL, S6_HPM)}')
print(f'Semana 6 - Teste t HI vs. HP = {ttest_ind(S6_HI, S6_HP)}')
print(f'Semana 6 - Teste t HI vs. HM = {ttest_ind(S6_HI, S6_HM)}')
print(f'Semana 6 - Teste t HI vs. HPM = {ttest_ind(S6_HI, S6_HPM)}')
print(f'Semana 6 - Teste t HP vs. HM = {ttest_ind(S6_HP, S6_HM)}')
print(f'Semana 6 - Teste t HP vs. HPM = {ttest_ind(S6_HI, S6_HPM)}')
print(f'Semana 6 - Teste t HM vs. HPM = {ttest_ind(S6_HI, S6_HPM)}')

print((140*"_"))

#|Semana 7|
sem7_P = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="K", skiprows=1, nrows=15)
S7_P = pd.DataFrame.dropna(sem7_P)
sem7_PP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="K", skiprows=20, nrows=15)
S7_PP = pd.DataFrame.dropna(sem7_PP)
sem7_HL = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="K", skiprows=39, nrows=15)
S7_HL = pd.DataFrame.dropna(sem7_HL)
sem7_HI = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="K", skiprows=58, nrows=15)
S7_HI = pd.DataFrame.dropna(sem7_HI)
sem7_HP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="K", skiprows=77, nrows=15)
S7_HP = pd.DataFrame.dropna(sem7_HP)
sem7_HM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="K", skiprows=96, nrows=15)
S7_HM = pd.DataFrame.dropna(sem7_HM)
sem7_HPM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="K", skiprows=115, nrows=15)
S7_HPM = pd.DataFrame.dropna(sem7_HPM)

print(f'Semana 7 - Teste t P vs. PP = {ttest_ind(S7_P, S7_PP)}')
print(f'Semana 7 - Teste t P vs. HL = {ttest_ind(S7_P, S7_HL)}')
print(f'Semana 7 - Teste t P vs. HI = {ttest_ind(S7_P, S7_HI)}')
print(f'Semana 7 - Teste t P vs. HP = {ttest_ind(S7_P, S7_HP)}')
print(f'Semana 7 - Teste t P vs. HM = {ttest_ind(S7_P, S7_HM)}')
print(f'Semana 7 - Teste t P vs. HPM = {ttest_ind(S7_P, S7_HPM)}')
print(f'Semana 7 - Teste t PP vs. HL = {ttest_ind(S7_PP, S7_HL)}')
print(f'Semana 7 - Teste t PP vs. HI = {ttest_ind(S7_PP, S7_HI)}')
print(f'Semana 7 - Teste t PP vs. HP = {ttest_ind(S7_PP, S7_HP)}')
print(f'Semana 7 - Teste t PP vs. HM = {ttest_ind(S7_PP, S7_HM)}')
print(f'Semana 7 - Teste t PP vs. HPM = {ttest_ind(S7_PP, S7_HPM)}')
print(f'Semana 7 - Teste t HL vs. HI = {ttest_ind(S7_HL, S7_HI)}')
print(f'Semana 7 - Teste t HL vs. HP = {ttest_ind(S7_HL, S7_HP)}')
print(f'Semana 7 - Teste t HL vs. HM = {ttest_ind(S7_HL, S7_HM)}')
print(f'Semana 7 - Teste t HL vs. HPM = {ttest_ind(S7_HL, S7_HPM)}')
print(f'Semana 7 - Teste t HI vs. HP = {ttest_ind(S7_HI, S7_HP)}')
print(f'Semana 7 - Teste t HI vs. HM = {ttest_ind(S7_HI, S7_HM)}')
print(f'Semana 7 - Teste t HI vs. HPM = {ttest_ind(S7_HI, S7_HPM)}')
print(f'Semana 7 - Teste t HP vs. HM = {ttest_ind(S7_HP, S7_HM)}')
print(f'Semana 7 - Teste t HP vs. HPM = {ttest_ind(S7_HI, S7_HPM)}')
print(f'Semana 7 - Teste t HM vs. HPM = {ttest_ind(S7_HI, S7_HPM)}')

print((140*"_"))

#|Semana 8|
sem8_P = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="L", skiprows=1, nrows=15)
S8_P = pd.DataFrame.dropna(sem8_P)
sem8_PP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="L", skiprows=20, nrows=15)
S8_PP = pd.DataFrame.dropna(sem8_PP)
sem8_HL = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="L", skiprows=39, nrows=15)
S8_HL = pd.DataFrame.dropna(sem8_HL)
sem8_HI = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="L", skiprows=58, nrows=15)
S8_HI = pd.DataFrame.dropna(sem8_HI)
sem8_HP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="L", skiprows=77, nrows=15)
S8_HP = pd.DataFrame.dropna(sem8_HP)
sem8_HM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="L", skiprows=96, nrows=15)
S8_HM = pd.DataFrame.dropna(sem8_HM)
sem8_HPM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="L", skiprows=115, nrows=15)
S8_HPM = pd.DataFrame.dropna(sem8_HPM)

print(f'Semana 8 - Teste t P vs. PP = {ttest_ind(S8_P, S8_PP)}')
print(f'Semana 8 - Teste t P vs. HL = {ttest_ind(S8_P, S8_HL)}')
print(f'Semana 8 - Teste t P vs. HI = {ttest_ind(S8_P, S8_HI)}')
print(f'Semana 8 - Teste t P vs. HP = {ttest_ind(S8_P, S8_HP)}')
print(f'Semana 8 - Teste t P vs. HM = {ttest_ind(S8_P, S8_HM)}')
print(f'Semana 8 - Teste t P vs. HPM = {ttest_ind(S8_P, S8_HPM)}')
print(f'Semana 8 - Teste t PP vs. HL = {ttest_ind(S8_PP, S8_HL)}')
print(f'Semana 8 - Teste t PP vs. HI = {ttest_ind(S8_PP, S8_HI)}')
print(f'Semana 8 - Teste t PP vs. HP = {ttest_ind(S8_PP, S8_HP)}')
print(f'Semana 8 - Teste t PP vs. HM = {ttest_ind(S8_PP, S8_HM)}')
print(f'Semana 8 - Teste t PP vs. HPM = {ttest_ind(S8_PP, S8_HPM)}')
print(f'Semana 8 - Teste t HL vs. HI = {ttest_ind(S8_HL, S8_HI)}')
print(f'Semana 8 - Teste t HL vs. HP = {ttest_ind(S8_HL, S8_HP)}')
print(f'Semana 8 - Teste t HL vs. HM = {ttest_ind(S8_HL, S8_HM)}')
print(f'Semana 8 - Teste t HL vs. HPM = {ttest_ind(S8_HL, S8_HPM)}')
print(f'Semana 8 - Teste t HI vs. HP = {ttest_ind(S8_HI, S8_HP)}')
print(f'Semana 8 - Teste t HI vs. HM = {ttest_ind(S8_HI, S8_HM)}')
print(f'Semana 8 - Teste t HI vs. HPM = {ttest_ind(S8_HI, S8_HPM)}')
print(f'Semana 8 - Teste t HP vs. HM = {ttest_ind(S8_HP, S8_HM)}')
print(f'Semana 8 - Teste t HP vs. HPM = {ttest_ind(S8_HI, S8_HPM)}')
print(f'Semana 8 - Teste t HM vs. HPM = {ttest_ind(S8_HI, S8_HPM)}')

print((140*"_"))

#|Semana 9|
sem9_P = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="M", skiprows=1, nrows=15)
S9_P = pd.DataFrame.dropna(sem9_P)
sem9_PP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="M", skiprows=20, nrows=15)
S9_PP = pd.DataFrame.dropna(sem9_PP)
sem9_HL = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="M", skiprows=39, nrows=15)
S9_HL = pd.DataFrame.dropna(sem9_HL)
sem9_HI = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="M", skiprows=58, nrows=15)
S9_HI = pd.DataFrame.dropna(sem9_HI)
sem9_HP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="M", skiprows=77, nrows=15)
S9_HP = pd.DataFrame.dropna(sem9_HP)
sem9_HM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="M", skiprows=96, nrows=15)
S9_HM = pd.DataFrame.dropna(sem9_HM)
sem9_HPM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="M", skiprows=115, nrows=15)
S9_HPM = pd.DataFrame.dropna(sem9_HPM)

print(f'Semana 9 - Teste t P vs. PP = {ttest_ind(S9_P, S9_PP)}')
print(f'Semana 9 - Teste t P vs. HL = {ttest_ind(S9_P, S9_HL)}')
print(f'Semana 9 - Teste t P vs. HI = {ttest_ind(S9_P, S9_HI)}')
print(f'Semana 9 - Teste t P vs. HP = {ttest_ind(S9_P, S9_HP)}')
print(f'Semana 9 - Teste t P vs. HM = {ttest_ind(S9_P, S9_HM)}')
print(f'Semana 9 - Teste t P vs. HPM = {ttest_ind(S9_P, S9_HPM)}')
print(f'Semana 9 - Teste t PP vs. HL = {ttest_ind(S9_PP, S9_HL)}')
print(f'Semana 9 - Teste t PP vs. HI = {ttest_ind(S9_PP, S9_HI)}')
print(f'Semana 9 - Teste t PP vs. HP = {ttest_ind(S9_PP, S9_HP)}')
print(f'Semana 9 - Teste t PP vs. HM = {ttest_ind(S9_PP, S9_HM)}')
print(f'Semana 9 - Teste t PP vs. HPM = {ttest_ind(S9_PP, S9_HPM)}')
print(f'Semana 9 - Teste t HL vs. HI = {ttest_ind(S9_HL, S9_HI)}')
print(f'Semana 9 - Teste t HL vs. HP = {ttest_ind(S9_HL, S9_HP)}')
print(f'Semana 9 - Teste t HL vs. HM = {ttest_ind(S9_HL, S9_HM)}')
print(f'Semana 9 - Teste t HL vs. HPM = {ttest_ind(S9_HL, S9_HPM)}')
print(f'Semana 9 - Teste t HI vs. HP = {ttest_ind(S9_HI, S9_HP)}')
print(f'Semana 9 - Teste t HI vs. HM = {ttest_ind(S9_HI, S9_HM)}')
print(f'Semana 9 - Teste t HI vs. HPM = {ttest_ind(S9_HI, S9_HPM)}')
print(f'Semana 9 - Teste t HP vs. HM = {ttest_ind(S9_HP, S9_HM)}')
print(f'Semana 9 - Teste t HP vs. HPM = {ttest_ind(S9_HI, S9_HPM)}')
print(f'Semana 9 - Teste t HM vs. HPM = {ttest_ind(S9_HI, S9_HPM)}')

print((140*"_"))

#|Semana 10|
sem10_P = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="N", skiprows=1, nrows=15)
S10_P = pd.DataFrame.dropna(sem10_P)
sem10_PP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="N", skiprows=20, nrows=15)
S10_PP = pd.DataFrame.dropna(sem10_PP)
sem10_HL = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="N", skiprows=39, nrows=15)
S10_HL = pd.DataFrame.dropna(sem10_HL)
sem10_HI = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="N", skiprows=58, nrows=15)
S10_HI = pd.DataFrame.dropna(sem10_HI)
sem10_HP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="N", skiprows=77, nrows=15)
S10_HP = pd.DataFrame.dropna(sem10_HP)
sem10_HM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="N", skiprows=96, nrows=15)
S10_HM = pd.DataFrame.dropna(sem10_HM)
sem10_HPM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="N", skiprows=115, nrows=15)
S10_HPM = pd.DataFrame.dropna(sem10_HPM)

print(f'Semana 10 - Teste t P vs. PP = {ttest_ind(S10_P, S10_PP)}')
print(f'Semana 10 - Teste t P vs. HL = {ttest_ind(S10_P, S10_HL)}')
print(f'Semana 10 - Teste t P vs. HI = {ttest_ind(S10_P, S10_HI)}')
print(f'Semana 10 - Teste t P vs. HP = {ttest_ind(S10_P, S10_HP)}')
print(f'Semana 10 - Teste t P vs. HM = {ttest_ind(S10_P, S10_HM)}')
print(f'Semana 10 - Teste t P vs. HPM = {ttest_ind(S10_P, S10_HPM)}')
print(f'Semana 10 - Teste t PP vs. HL = {ttest_ind(S10_PP, S10_HL)}')
print(f'Semana 10 - Teste t PP vs. HI = {ttest_ind(S10_PP, S10_HI)}')
print(f'Semana 10 - Teste t PP vs. HP = {ttest_ind(S10_PP, S10_HP)}')
print(f'Semana 10 - Teste t PP vs. HM = {ttest_ind(S10_PP, S10_HM)}')
print(f'Semana 10 - Teste t PP vs. HPM = {ttest_ind(S10_PP, S10_HPM)}')
print(f'Semana 10 - Teste t HL vs. HI = {ttest_ind(S10_HL, S10_HI)}')
print(f'Semana 10 - Teste t HL vs. HP = {ttest_ind(S10_HL, S10_HP)}')
print(f'Semana 10 - Teste t HL vs. HM = {ttest_ind(S10_HL, S10_HM)}')
print(f'Semana 10 - Teste t HL vs. HPM = {ttest_ind(S10_HL, S10_HPM)}')
print(f'Semana 10 - Teste t HI vs. HP = {ttest_ind(S10_HI, S10_HP)}')
print(f'Semana 10 - Teste t HI vs. HM = {ttest_ind(S10_HI, S10_HM)}')
print(f'Semana 10 - Teste t HI vs. HPM = {ttest_ind(S10_HI, S10_HPM)}')
print(f'Semana 10 - Teste t HP vs. HM = {ttest_ind(S10_HP, S10_HM)}')
print(f'Semana 10 - Teste t HP vs. HPM = {ttest_ind(S10_HI, S10_HPM)}')
print(f'Semana 10 - Teste t HM vs. HPM = {ttest_ind(S10_HI, S10_HPM)}')

print((140*"_"))

#|Semana 11|
sem11_P = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="O", skiprows=1, nrows=15)
S11_P = pd.DataFrame.dropna(sem11_P)
sem11_PP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="O", skiprows=20, nrows=15)
S11_PP = pd.DataFrame.dropna(sem11_PP)
sem11_HL = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="O", skiprows=39, nrows=15)
S11_HL = pd.DataFrame.dropna(sem11_HL)
sem11_HI = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="O", skiprows=58, nrows=15)
S11_HI = pd.DataFrame.dropna(sem11_HI)
sem11_HP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="O", skiprows=77, nrows=15)
S11_HP = pd.DataFrame.dropna(sem11_HP)
sem11_HM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="O", skiprows=96, nrows=15)
S11_HM = pd.DataFrame.dropna(sem11_HM)
sem11_HPM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="O", skiprows=115, nrows=15)
S11_HPM = pd.DataFrame.dropna(sem11_HPM)

print(f'Semana 11 - Teste t P vs. PP = {ttest_ind(S11_P, S11_PP)}')
print(f'Semana 11 - Teste t P vs. HL = {ttest_ind(S11_P, S11_HL)}')
print(f'Semana 11 - Teste t P vs. HI = {ttest_ind(S11_P, S11_HI)}')
print(f'Semana 11 - Teste t P vs. HP = {ttest_ind(S11_P, S11_HP)}')
print(f'Semana 11 - Teste t P vs. HM = {ttest_ind(S11_P, S11_HM)}')
print(f'Semana 11 - Teste t P vs. HPM = {ttest_ind(S11_P, S11_HPM)}')
print(f'Semana 11 - Teste t PP vs. HL = {ttest_ind(S11_PP, S11_HL)}')
print(f'Semana 11 - Teste t PP vs. HI = {ttest_ind(S11_PP, S11_HI)}')
print(f'Semana 11 - Teste t PP vs. HP = {ttest_ind(S11_PP, S11_HP)}')
print(f'Semana 11 - Teste t PP vs. HM = {ttest_ind(S11_PP, S11_HM)}')
print(f'Semana 11 - Teste t PP vs. HPM = {ttest_ind(S11_PP, S11_HPM)}')
print(f'Semana 11 - Teste t HL vs. HI = {ttest_ind(S11_HL, S11_HI)}')
print(f'Semana 11 - Teste t HL vs. HP = {ttest_ind(S11_HL, S11_HP)}')
print(f'Semana 11 - Teste t HL vs. HM = {ttest_ind(S11_HL, S11_HM)}')
print(f'Semana 11 - Teste t HL vs. HPM = {ttest_ind(S11_HL, S11_HPM)}')
print(f'Semana 11 - Teste t HI vs. HP = {ttest_ind(S11_HI, S11_HP)}')
print(f'Semana 11 - Teste t HI vs. HM = {ttest_ind(S11_HI, S11_HM)}')
print(f'Semana 11 - Teste t HI vs. HPM = {ttest_ind(S11_HI, S11_HPM)}')
print(f'Semana 11 - Teste t HP vs. HM = {ttest_ind(S11_HP, S11_HM)}')
print(f'Semana 11 - Teste t HP vs. HPM = {ttest_ind(S11_HI, S11_HPM)}')
print(f'Semana 11 - Teste t HM vs. HPM = {ttest_ind(S11_HI, S11_HPM)}')

print((140*"_"))

#|Semana 12|
sem12_P = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="P", skiprows=1, nrows=15)
S12_P = pd.DataFrame.dropna(sem12_P)
sem12_PP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="P", skiprows=20, nrows=15)
S12_PP = pd.DataFrame.dropna(sem12_PP)
sem12_HL = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="P", skiprows=39, nrows=15)
S12_HL = pd.DataFrame.dropna(sem12_HL)
sem12_HI = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="P", skiprows=58, nrows=15)
S12_HI = pd.DataFrame.dropna(sem12_HI)
sem12_HP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="P", skiprows=77, nrows=15)
S12_HP = pd.DataFrame.dropna(sem12_HP)
sem12_HM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="P", skiprows=96, nrows=15)
S12_HM = pd.DataFrame.dropna(sem12_HM)
sem12_HPM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="P", skiprows=115, nrows=15)
S12_HPM = pd.DataFrame.dropna(sem12_HPM)

print(f'Semana 12 - Teste t P vs. PP = {ttest_ind(S12_P, S12_PP)}')
print(f'Semana 12 - Teste t P vs. HL = {ttest_ind(S12_P, S12_HL)}')
print(f'Semana 12 - Teste t P vs. HI = {ttest_ind(S12_P, S12_HI)}')
print(f'Semana 12 - Teste t P vs. HP = {ttest_ind(S12_P, S12_HP)}')
print(f'Semana 12 - Teste t P vs. HM = {ttest_ind(S12_P, S12_HM)}')
print(f'Semana 12 - Teste t P vs. HPM = {ttest_ind(S12_P, S12_HPM)}')
print(f'Semana 12 - Teste t PP vs. HL = {ttest_ind(S12_PP, S12_HL)}')
print(f'Semana 12 - Teste t PP vs. HI = {ttest_ind(S12_PP, S12_HI)}')
print(f'Semana 12 - Teste t PP vs. HP = {ttest_ind(S12_PP, S12_HP)}')
print(f'Semana 12 - Teste t PP vs. HM = {ttest_ind(S12_PP, S12_HM)}')
print(f'Semana 12 - Teste t PP vs. HPM = {ttest_ind(S12_PP, S12_HPM)}')
print(f'Semana 12 - Teste t HL vs. HI = {ttest_ind(S12_HL, S12_HI)}')
print(f'Semana 12 - Teste t HL vs. HP = {ttest_ind(S12_HL, S12_HP)}')
print(f'Semana 12 - Teste t HL vs. HM = {ttest_ind(S12_HL, S12_HM)}')
print(f'Semana 12 - Teste t HL vs. HPM = {ttest_ind(S12_HL, S12_HPM)}')
print(f'Semana 12 - Teste t HI vs. HP = {ttest_ind(S12_HI, S12_HP)}')
print(f'Semana 12 - Teste t HI vs. HM = {ttest_ind(S12_HI, S12_HM)}')
print(f'Semana 12 - Teste t HI vs. HPM = {ttest_ind(S12_HI, S12_HPM)}')
print(f'Semana 12 - Teste t HP vs. HM = {ttest_ind(S12_HP, S12_HM)}')
print(f'Semana 12 - Teste t HP vs. HPM = {ttest_ind(S12_HI, S12_HPM)}')
print(f'Semana 12 - Teste t HM vs. HPM = {ttest_ind(S12_HI, S12_HPM)}')

print((140*"_"))

#|Semana 13|
sem13_P = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="Q", skiprows=1, nrows=15)
S13_P = pd.DataFrame.dropna(sem13_P)
sem13_PP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="Q", skiprows=20, nrows=15)
S13_PP = pd.DataFrame.dropna(sem13_PP)
sem13_HL = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="Q", skiprows=39, nrows=15)
S13_HL = pd.DataFrame.dropna(sem13_HL)
sem13_HI = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="Q", skiprows=58, nrows=15)
S13_HI = pd.DataFrame.dropna(sem13_HI)
sem13_HP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="Q", skiprows=77, nrows=15)
S13_HP = pd.DataFrame.dropna(sem13_HP)
sem13_HM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="Q", skiprows=96, nrows=15)
S13_HM = pd.DataFrame.dropna(sem13_HM)
sem13_HPM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="Q", skiprows=115, nrows=15)
S13_HPM = pd.DataFrame.dropna(sem13_HPM)

print(f'Semana 13 - Teste t P vs. PP = {ttest_ind(S13_P, S13_PP)}')
print(f'Semana 13 - Teste t P vs. HL = {ttest_ind(S13_P, S13_HL)}')
print(f'Semana 13 - Teste t P vs. HI = {ttest_ind(S13_P, S13_HI)}')
print(f'Semana 13 - Teste t P vs. HP = {ttest_ind(S13_P, S13_HP)}')
print(f'Semana 13 - Teste t P vs. HM = {ttest_ind(S13_P, S13_HM)}')
print(f'Semana 13 - Teste t P vs. HPM = {ttest_ind(S13_P, S13_HPM)}')
print(f'Semana 13 - Teste t PP vs. HL = {ttest_ind(S13_PP, S13_HL)}')
print(f'Semana 13 - Teste t PP vs. HI = {ttest_ind(S13_PP, S13_HI)}')
print(f'Semana 13 - Teste t PP vs. HP = {ttest_ind(S13_PP, S13_HP)}')
print(f'Semana 13 - Teste t PP vs. HM = {ttest_ind(S13_PP, S13_HM)}')
print(f'Semana 13 - Teste t PP vs. HPM = {ttest_ind(S13_PP, S13_HPM)}')
print(f'Semana 13 - Teste t HL vs. HI = {ttest_ind(S13_HL, S13_HI)}')
print(f'Semana 13 - Teste t HL vs. HP = {ttest_ind(S13_HL, S13_HP)}')
print(f'Semana 13 - Teste t HL vs. HM = {ttest_ind(S13_HL, S13_HM)}')
print(f'Semana 13 - Teste t HL vs. HPM = {ttest_ind(S13_HL, S13_HPM)}')
print(f'Semana 13 - Teste t HI vs. HP = {ttest_ind(S13_HI, S13_HP)}')
print(f'Semana 13 - Teste t HI vs. HM = {ttest_ind(S13_HI, S13_HM)}')
print(f'Semana 13 - Teste t HI vs. HPM = {ttest_ind(S13_HI, S13_HPM)}')
print(f'Semana 13 - Teste t HP vs. HM = {ttest_ind(S13_HP, S13_HM)}')
print(f'Semana 13 - Teste t HP vs. HPM = {ttest_ind(S13_HI, S13_HPM)}')
print(f'Semana 13 - Teste t HM vs. HPM = {ttest_ind(S13_HI, S13_HPM)}')

print((140*"_"))

#|Semana 14|
sem14_P = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="R", skiprows=1, nrows=15)
S14_P = pd.DataFrame.dropna(sem14_P)
sem14_PP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="R", skiprows=20, nrows=15)
S14_PP = pd.DataFrame.dropna(sem14_PP)
sem14_HL = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="R", skiprows=39, nrows=15)
S14_HL = pd.DataFrame.dropna(sem14_HL)
sem14_HI = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="R", skiprows=58, nrows=15)
S14_HI = pd.DataFrame.dropna(sem14_HI)
sem14_HP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="R", skiprows=77, nrows=15)
S14_HP = pd.DataFrame.dropna(sem14_HP)
sem14_HM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="R", skiprows=96, nrows=15)
S14_HM = pd.DataFrame.dropna(sem14_HM)
sem14_HPM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="R", skiprows=115, nrows=15)
S14_HPM = pd.DataFrame.dropna(sem14_HPM)

print(f'Semana 14 - Teste t P vs. PP = {ttest_ind(S14_P, S14_PP)}')
print(f'Semana 14 - Teste t P vs. HL = {ttest_ind(S14_P, S14_HL)}')
print(f'Semana 14 - Teste t P vs. HI = {ttest_ind(S14_P, S14_HI)}')
print(f'Semana 14 - Teste t P vs. HP = {ttest_ind(S14_P, S14_HP)}')
print(f'Semana 14 - Teste t P vs. HM = {ttest_ind(S14_P, S14_HM)}')
print(f'Semana 14 - Teste t P vs. HPM = {ttest_ind(S14_P, S14_HPM)}')
print(f'Semana 14 - Teste t PP vs. HL = {ttest_ind(S14_PP, S14_HL)}')
print(f'Semana 14 - Teste t PP vs. HI = {ttest_ind(S14_PP, S14_HI)}')
print(f'Semana 14 - Teste t PP vs. HP = {ttest_ind(S14_PP, S14_HP)}')
print(f'Semana 14 - Teste t PP vs. HM = {ttest_ind(S14_PP, S14_HM)}')
print(f'Semana 14 - Teste t PP vs. HPM = {ttest_ind(S14_PP, S14_HPM)}')
print(f'Semana 14 - Teste t HL vs. HI = {ttest_ind(S14_HL, S14_HI)}')
print(f'Semana 14 - Teste t HL vs. HP = {ttest_ind(S14_HL, S14_HP)}')
print(f'Semana 14 - Teste t HL vs. HM = {ttest_ind(S14_HL, S14_HM)}')
print(f'Semana 14 - Teste t HL vs. HPM = {ttest_ind(S14_HL, S14_HPM)}')
print(f'Semana 14 - Teste t HI vs. HP = {ttest_ind(S14_HI, S14_HP)}')
print(f'Semana 14 - Teste t HI vs. HM = {ttest_ind(S14_HI, S14_HM)}')
print(f'Semana 14 - Teste t HI vs. HPM = {ttest_ind(S14_HI, S14_HPM)}')
print(f'Semana 14 - Teste t HP vs. HM = {ttest_ind(S14_HP, S14_HM)}')
print(f'Semana 14 - Teste t HP vs. HPM = {ttest_ind(S14_HI, S14_HPM)}')
print(f'Semana 14 - Teste t HM vs. HPM = {ttest_ind(S14_HI, S14_HPM)}')

print((140*"_"))

#|Semana 15|
sem15_P = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="S", skiprows=1, nrows=15)
S15_P = pd.DataFrame.dropna(sem15_P)
sem15_PP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="S", skiprows=20, nrows=15)
S15_PP = pd.DataFrame.dropna(sem15_PP)
sem15_HL = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="S", skiprows=39, nrows=15)
S15_HL = pd.DataFrame.dropna(sem15_HL)
sem15_HI = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="S", skiprows=58, nrows=15)
S15_HI = pd.DataFrame.dropna(sem15_HI)
sem15_HP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="S", skiprows=77, nrows=15)
S15_HP = pd.DataFrame.dropna(sem15_HP)
sem15_HM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="S", skiprows=96, nrows=15)
S15_HM = pd.DataFrame.dropna(sem15_HM)
sem15_HPM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="S", skiprows=115, nrows=15)
S15_HPM = pd.DataFrame.dropna(sem15_HPM)

print(f'Semana 15 - Teste t P vs. PP = {ttest_ind(S15_P, S15_PP)}')
print(f'Semana 15 - Teste t P vs. HL = {ttest_ind(S15_P, S15_HL)}')
print(f'Semana 15 - Teste t P vs. HI = {ttest_ind(S15_P, S15_HI)}')
print(f'Semana 15 - Teste t P vs. HP = {ttest_ind(S15_P, S15_HP)}')
print(f'Semana 15 - Teste t P vs. HM = {ttest_ind(S15_P, S15_HM)}')
print(f'Semana 15 - Teste t P vs. HPM = {ttest_ind(S15_P, S15_HPM)}')
print(f'Semana 15 - Teste t PP vs. HL = {ttest_ind(S15_PP, S15_HL)}')
print(f'Semana 15 - Teste t PP vs. HI = {ttest_ind(S15_PP, S15_HI)}')
print(f'Semana 15 - Teste t PP vs. HP = {ttest_ind(S15_PP, S15_HP)}')
print(f'Semana 15 - Teste t PP vs. HM = {ttest_ind(S15_PP, S15_HM)}')
print(f'Semana 15 - Teste t PP vs. HPM = {ttest_ind(S15_PP, S15_HPM)}')
print(f'Semana 15 - Teste t HL vs. HI = {ttest_ind(S15_HL, S15_HI)}')
print(f'Semana 15 - Teste t HL vs. HP = {ttest_ind(S15_HL, S15_HP)}')
print(f'Semana 15 - Teste t HL vs. HM = {ttest_ind(S15_HL, S15_HM)}')
print(f'Semana 15 - Teste t HL vs. HPM = {ttest_ind(S15_HL, S15_HPM)}')
print(f'Semana 15 - Teste t HI vs. HP = {ttest_ind(S15_HI, S15_HP)}')
print(f'Semana 15 - Teste t HI vs. HM = {ttest_ind(S15_HI, S15_HM)}')
print(f'Semana 15 - Teste t HI vs. HPM = {ttest_ind(S15_HI, S15_HPM)}')
print(f'Semana 15 - Teste t HP vs. HM = {ttest_ind(S15_HP, S15_HM)}')
print(f'Semana 15 - Teste t HP vs. HPM = {ttest_ind(S15_HI, S15_HPM)}')
print(f'Semana 15 - Teste t HM vs. HPM = {ttest_ind(S15_HI, S15_HPM)}')

print((140*"_"))

#|Semana 16|
sem16_P = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="T", skiprows=1, nrows=15)
S16_P = pd.DataFrame.dropna(sem16_P)
sem16_PP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="T", skiprows=20, nrows=15)
S16_PP = pd.DataFrame.dropna(sem16_PP)
sem16_HL = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="T", skiprows=39, nrows=15)
S16_HL = pd.DataFrame.dropna(sem16_HL)
sem16_HI = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="T", skiprows=58, nrows=15)
S16_HI = pd.DataFrame.dropna(sem16_HI)
sem16_HP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="T", skiprows=77, nrows=15)
S16_HP = pd.DataFrame.dropna(sem16_HP)
sem16_HM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="T", skiprows=96, nrows=15)
S16_HM = pd.DataFrame.dropna(sem16_HM)
sem16_HPM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="T", skiprows=115, nrows=15)
S16_HPM = pd.DataFrame.dropna(sem16_HPM)

print(f'Semana 16 - Teste t P vs. PP = {ttest_ind(S16_P, S16_PP)}')
print(f'Semana 15 - Teste t P vs. HL = {ttest_ind(S16_P, S16_HL)}')
print(f'Semana 15 - Teste t P vs. HI = {ttest_ind(S16_P, S16_HI)}')
print(f'Semana 16 - Teste t P vs. HP = {ttest_ind(S15_P, S16_HP)}')
print(f'Semana 16 - Teste t P vs. HM = {ttest_ind(S16_P, S16_HM)}')
print(f'Semana 16 - Teste t P vs. HPM = {ttest_ind(S16_P, S16_HPM)}')
print(f'Semana 16 - Teste t PP vs. HL = {ttest_ind(S16_PP, S16_HL)}')
print(f'Semana 16 - Teste t PP vs. HI = {ttest_ind(S16_PP, S16_HI)}')
print(f'Semana 16 - Teste t PP vs. HP = {ttest_ind(S16_PP, S16_HP)}')
print(f'Semana 16 - Teste t PP vs. HM = {ttest_ind(S16_PP, S16_HM)}')
print(f'Semana 16 - Teste t PP vs. HPM = {ttest_ind(S16_PP, S16_HPM)}')
print(f'Semana 16 - Teste t HL vs. HI = {ttest_ind(S16_HL, S16_HI)}')
print(f'Semana 16 - Teste t HL vs. HP = {ttest_ind(S16_HL, S16_HP)}')
print(f'Semana 16 - Teste t HL vs. HM = {ttest_ind(S16_HL, S16_HM)}')
print(f'Semana 16 - Teste t HL vs. HPM = {ttest_ind(S16_HL, S16_HPM)}')
print(f'Semana 16 - Teste t HI vs. HP = {ttest_ind(S16_HI, S16_HP)}')
print(f'Semana 16 - Teste t HI vs. HM = {ttest_ind(S16_HI, S16_HM)}')
print(f'Semana 16 - Teste t HI vs. HPM = {ttest_ind(S16_HI, S16_HPM)}')
print(f'Semana 16 - Teste t HP vs. HM = {ttest_ind(S16_HP, S16_HM)}')
print(f'Semana 16 - Teste t HP vs. HPM = {ttest_ind(S16_HI, S16_HPM)}')
print(f'Semana 16 - Teste t HM vs. HPM = {ttest_ind(S16_HI, S16_HPM)}')

# %% [markdown]
# ####**3.1.2. Dados ingestão alimentar semanal**

# %%
#Importação de bibliotecas
import pandas as pd
import numpy as np
from scipy.stats import ttest_ind

#|Semana 1|
sem1_P = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="D:H", skiprows=8, nrows=1)
S1_P = np.transpose(sem1_P)
sem1_PP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="D:H", skiprows=20, nrows=1)
S1_PP = np.transpose(sem1_PP)
sem1_HL = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="D:H", skiprows=32, nrows=1)
S1_HL = np.transpose(sem1_HL)
sem1_HI = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="D:H", skiprows=44, nrows=1)
S1_HI = np.transpose(sem1_HI)
sem1_HP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="D:H", skiprows=56, nrows=1)
S1_HP = np.transpose(sem1_HP)
sem1_HM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="D:H", skiprows=68, nrows=1)
S1_HM = np.transpose(sem1_HM)
sem1_HPM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="D:H", skiprows=80, nrows=1)
S1_HPM = np.transpose(sem1_HPM)

print(f'Semana 1 - Teste t P vs. PP = {ttest_ind(S1_P, S1_PP)}')
print(f'Semana 1 - Teste t P vs. HL = {ttest_ind(S1_P, S1_HL)}')
print(f'Semana 1 - Teste t P vs. HI = {ttest_ind(S1_P, S1_HI)}')
print(f'Semana 1 - Teste t P vs. HP = {ttest_ind(S1_P, S1_HP)}')
print(f'Semana 1 - Teste t P vs. HM = {ttest_ind(S1_P, S1_HM)}')
print(f'Semana 1 - Teste t P vs. HPM = {ttest_ind(S1_P, S1_HPM)}')
print(f'Semana 1 - Teste t PP vs. HL = {ttest_ind(S1_PP, S1_HL)}')
print(f'Semana 1 - Teste t PP vs. HI = {ttest_ind(S1_PP, S1_HI)}')
print(f'Semana 1 - Teste t PP vs. HP = {ttest_ind(S1_PP, S1_HP)}')
print(f'Semana 1 - Teste t PP vs. HM = {ttest_ind(S1_PP, S1_HM)}')
print(f'Semana 1 - Teste t PP vs. HPM = {ttest_ind(S1_PP, S1_HPM)}')
print(f'Semana 1 - Teste t HL vs. HI = {ttest_ind(S1_HL, S1_HI)}')
print(f'Semana 1 - Teste t HL vs. HP = {ttest_ind(S1_HL, S1_HP)}')
print(f'Semana 1 - Teste t HL vs. HM = {ttest_ind(S1_HL, S1_HM)}')
print(f'Semana 1 - Teste t HL vs. HPM = {ttest_ind(S1_HL, S1_HPM)}')
print(f'Semana 1 - Teste t HI vs. HP = {ttest_ind(S1_HI, S1_HP)}')
print(f'Semana 1 - Teste t HI vs. HM = {ttest_ind(S1_HI, S1_HM)}')
print(f'Semana 1 - Teste t HI vs. HPM = {ttest_ind(S1_HI, S1_HPM)}')
print(f'Semana 1 - Teste t HP vs. HM = {ttest_ind(S1_HP, S1_HM)}')
print(f'Semana 1 - Teste t HP vs. HPM = {ttest_ind(S1_HI, S1_HPM)}')
print(f'Semana 1 - Teste t HM vs. HPM = {ttest_ind(S1_HI, S1_HPM)}')

print((140*"_"))

#|Semana 2|
sem2_P = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="I:M", skiprows=8, nrows=1)
S2_P = np.transpose(sem2_P)
sem2_PP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="I:M", skiprows=20, nrows=1)
S2_PP = np.transpose(sem2_PP)
sem2_HL = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="I:M", skiprows=32, nrows=1)
S2_HL = np.transpose(sem2_HL)
sem2_HI = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="I:M", skiprows=44, nrows=1)
S2_HI = np.transpose(sem2_HI)
sem2_HP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="I:M", skiprows=56, nrows=1)
S2_HP = np.transpose(sem2_HP)
sem2_HM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="I:M", skiprows=68, nrows=1)
S2_HM = np.transpose(sem2_HM)
sem2_HPM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="I:M", skiprows=80, nrows=1)
S2_HPM = np.transpose(sem2_HPM)

print(f'Semana 2 - Teste t P vs. PP = {ttest_ind(S2_P, S2_PP)}')
print(f'Semana 2 - Teste t P vs. HL = {ttest_ind(S2_P, S2_HL)}')
print(f'Semana 2 - Teste t P vs. HI = {ttest_ind(S2_P, S2_HI)}')
print(f'Semana 2 - Teste t P vs. HP = {ttest_ind(S2_P, S2_HP)}')
print(f'Semana 2 - Teste t P vs. HM = {ttest_ind(S2_P, S2_HM)}')
print(f'Semana 2 - Teste t P vs. HPM = {ttest_ind(S2_P, S2_HPM)}')
print(f'Semana 2 - Teste t PP vs. HL = {ttest_ind(S2_PP, S2_HL)}')
print(f'Semana 2 - Teste t PP vs. HI = {ttest_ind(S2_PP, S2_HI)}')
print(f'Semana 2 - Teste t PP vs. HP = {ttest_ind(S2_PP, S2_HP)}')
print(f'Semana 2 - Teste t PP vs. HM = {ttest_ind(S2_PP, S2_HM)}')
print(f'Semana 2 - Teste t PP vs. HPM = {ttest_ind(S2_PP, S2_HPM)}')
print(f'Semana 2 - Teste t HL vs. HI = {ttest_ind(S2_HL, S2_HI)}')
print(f'Semana 2 - Teste t HL vs. HP = {ttest_ind(S2_HL, S2_HP)}')
print(f'Semana 2 - Teste t HL vs. HM = {ttest_ind(S2_HL, S2_HM)}')
print(f'Semana 2 - Teste t HL vs. HPM = {ttest_ind(S2_HL, S2_HPM)}')
print(f'Semana 2 - Teste t HI vs. HP = {ttest_ind(S2_HI, S2_HP)}')
print(f'Semana 2 - Teste t HI vs. HM = {ttest_ind(S2_HI, S2_HM)}')
print(f'Semana 2 - Teste t HI vs. HPM = {ttest_ind(S2_HI, S2_HPM)}')
print(f'Semana 2 - Teste t HP vs. HM = {ttest_ind(S2_HP, S2_HM)}')
print(f'Semana 2 - Teste t HP vs. HPM = {ttest_ind(S2_HI, S2_HPM)}')
print(f'Semana 2 - Teste t HM vs. HPM = {ttest_ind(S2_HI, S2_HPM)}')

print((140*"_"))

#|Semana 3|
sem3_P = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="N:R", skiprows=8, nrows=1)
S3_P = np.transpose(sem3_P)
sem3_PP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="N:R", skiprows=20, nrows=1)
S3_PP = np.transpose(sem3_PP)
sem3_HL = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="N:R", skiprows=32, nrows=1)
S3_HL = np.transpose(sem3_HL)
sem3_HI = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="N:R", skiprows=44, nrows=1)
S3_HI = np.transpose(sem3_HI)
sem3_HP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="N:R", skiprows=56, nrows=1)
S3_HP = np.transpose(sem3_HP)
sem3_HM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="N:R", skiprows=68, nrows=1)
S3_HM = np.transpose(sem3_HM)
sem3_HPM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="N:R", skiprows=80, nrows=1)
S3_HPM = np.transpose(sem3_HPM)

print(f'Semana 3 - Teste t P vs. PP = {ttest_ind(S3_P, S3_PP)}')
print(f'Semana 3 - Teste t P vs. HL = {ttest_ind(S3_P, S3_HL)}')
print(f'Semana 3 - Teste t P vs. HI = {ttest_ind(S3_P, S3_HI)}')
print(f'Semana 3 - Teste t P vs. HP = {ttest_ind(S3_P, S3_HP)}')
print(f'Semana 3 - Teste t P vs. HM = {ttest_ind(S3_P, S3_HM)}')
print(f'Semana 3 - Teste t P vs. HPM = {ttest_ind(S3_P, S3_HPM)}')
print(f'Semana 3 - Teste t PP vs. HL = {ttest_ind(S3_PP, S3_HL)}')
print(f'Semana 3 - Teste t PP vs. HI = {ttest_ind(S3_PP, S3_HI)}')
print(f'Semana 3 - Teste t PP vs. HP = {ttest_ind(S3_PP, S3_HP)}')
print(f'Semana 3 - Teste t PP vs. HM = {ttest_ind(S3_PP, S3_HM)}')
print(f'Semana 3 - Teste t PP vs. HPM = {ttest_ind(S3_PP, S3_HPM)}')
print(f'Semana 3 - Teste t HL vs. HI = {ttest_ind(S3_HL, S3_HI)}')
print(f'Semana 3 - Teste t HL vs. HP = {ttest_ind(S3_HL, S3_HP)}')
print(f'Semana 3 - Teste t HL vs. HM = {ttest_ind(S3_HL, S3_HM)}')
print(f'Semana 3 - Teste t HL vs. HPM = {ttest_ind(S3_HL, S3_HPM)}')
print(f'Semana 3 - Teste t HI vs. HP = {ttest_ind(S3_HI, S3_HP)}')
print(f'Semana 3 - Teste t HI vs. HM = {ttest_ind(S3_HI, S3_HM)}')
print(f'Semana 3 - Teste t HI vs. HPM = {ttest_ind(S3_HI, S3_HPM)}')
print(f'Semana 3 - Teste t HP vs. HM = {ttest_ind(S3_HP, S3_HM)}')
print(f'Semana 3 - Teste t HP vs. HPM = {ttest_ind(S3_HI, S3_HPM)}')
print(f'Semana 3 - Teste t HM vs. HPM = {ttest_ind(S3_HI, S3_HPM)}')

print((140*"_"))

#|Semana 4|
sem4_P = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="S:W", skiprows=8, nrows=1)
S4_P = np.transpose(sem4_P)
sem4_PP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="S:W", skiprows=20, nrows=1)
S4_PP = np.transpose(sem4_PP)
sem4_HL = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="S:W", skiprows=32, nrows=1)
S4_HL = np.transpose(sem4_HL)
sem4_HI = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="S:W", skiprows=44, nrows=1)
S4_HI = np.transpose(sem4_HI)
sem4_HP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="S:W", skiprows=56, nrows=1)
S4_HP = np.transpose(sem4_HP)
sem4_HM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="S:W", skiprows=68, nrows=1)
S4_HM = np.transpose(sem4_HM)
sem4_HPM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="S:W", skiprows=80, nrows=1)
S4_HPM = np.transpose(sem4_HPM)

print(f'Semana 4 - Teste t P vs. PP = {ttest_ind(S4_P, S4_PP)}')
print(f'Semana 4 - Teste t P vs. HL = {ttest_ind(S4_P, S4_HL)}')
print(f'Semana 4 - Teste t P vs. HI = {ttest_ind(S4_P, S4_HI)}')
print(f'Semana 4 - Teste t P vs. HP = {ttest_ind(S4_P, S4_HP)}')
print(f'Semana 4 - Teste t P vs. HM = {ttest_ind(S4_P, S4_HM)}')
print(f'Semana 4 - Teste t P vs. HPM = {ttest_ind(S4_P, S4_HPM)}')
print(f'Semana 4 - Teste t PP vs. HL = {ttest_ind(S4_PP, S4_HL)}')
print(f'Semana 4 - Teste t PP vs. HI = {ttest_ind(S4_PP, S4_HI)}')
print(f'Semana 4 - Teste t PP vs. HP = {ttest_ind(S4_PP, S4_HP)}')
print(f'Semana 4 - Teste t PP vs. HM = {ttest_ind(S4_PP, S4_HM)}')
print(f'Semana 4 - Teste t PP vs. HPM = {ttest_ind(S4_PP, S4_HPM)}')
print(f'Semana 4 - Teste t HL vs. HI = {ttest_ind(S4_HL, S4_HI)}')
print(f'Semana 4 - Teste t HL vs. HP = {ttest_ind(S4_HL, S4_HP)}')
print(f'Semana 4 - Teste t HL vs. HM = {ttest_ind(S4_HL, S4_HM)}')
print(f'Semana 4 - Teste t HL vs. HPM = {ttest_ind(S4_HL, S4_HPM)}')
print(f'Semana 4 - Teste t HI vs. HP = {ttest_ind(S4_HI, S4_HP)}')
print(f'Semana 4 - Teste t HI vs. HM = {ttest_ind(S4_HI, S4_HM)}')
print(f'Semana 4 - Teste t HI vs. HPM = {ttest_ind(S4_HI, S4_HPM)}')
print(f'Semana 4 - Teste t HP vs. HM = {ttest_ind(S4_HP, S4_HM)}')
print(f'Semana 4 - Teste t HP vs. HPM = {ttest_ind(S4_HI, S4_HPM)}')
print(f'Semana 4 - Teste t HM vs. HPM = {ttest_ind(S4_HI, S4_HPM)}')

print((140*"_"))

#|Semana 5|
sem5_P = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="X:AB", skiprows=8, nrows=1)
S5_P = np.transpose(sem5_P)
sem5_PP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="X:AB", skiprows=20, nrows=1)
S5_PP = np.transpose(sem5_PP)
sem5_HL = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="X:AB", skiprows=32, nrows=1)
S5_HL = np.transpose(sem5_HL)
sem5_HI = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="X:AB", skiprows=44, nrows=1)
S5_HI = np.transpose(sem5_HI)
sem5_HP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="X:AB", skiprows=56, nrows=1)
S5_HP = np.transpose(sem5_HP)
sem5_HM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="X:AB", skiprows=68, nrows=1)
S5_HM = np.transpose(sem5_HM)
sem5_HPM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="X:AB", skiprows=80, nrows=1)
S5_HPM = np.transpose(sem5_HPM)

print(f'Semana 5 - Teste t P vs. PP = {ttest_ind(S5_P, S5_PP)}')
print(f'Semana 5 - Teste t P vs. HL = {ttest_ind(S5_P, S5_HL)}')
print(f'Semana 5 - Teste t P vs. HI = {ttest_ind(S5_P, S5_HI)}')
print(f'Semana 5 - Teste t P vs. HP = {ttest_ind(S5_P, S5_HP)}')
print(f'Semana 5 - Teste t P vs. HM = {ttest_ind(S5_P, S5_HM)}')
print(f'Semana 5 - Teste t P vs. HPM = {ttest_ind(S5_P, S5_HPM)}')
print(f'Semana 5 - Teste t PP vs. HL = {ttest_ind(S5_PP, S5_HL)}')
print(f'Semana 5 - Teste t PP vs. HI = {ttest_ind(S5_PP, S5_HI)}')
print(f'Semana 5 - Teste t PP vs. HP = {ttest_ind(S5_PP, S5_HP)}')
print(f'Semana 5 - Teste t PP vs. HM = {ttest_ind(S5_PP, S5_HM)}')
print(f'Semana 5 - Teste t PP vs. HPM = {ttest_ind(S5_PP, S5_HPM)}')
print(f'Semana 5 - Teste t HL vs. HI = {ttest_ind(S5_HL, S5_HI)}')
print(f'Semana 5 - Teste t HL vs. HP = {ttest_ind(S5_HL, S5_HP)}')
print(f'Semana 5 - Teste t HL vs. HM = {ttest_ind(S5_HL, S5_HM)}')
print(f'Semana 5 - Teste t HL vs. HPM = {ttest_ind(S5_HL, S5_HPM)}')
print(f'Semana 5 - Teste t HI vs. HP = {ttest_ind(S5_HI, S5_HP)}')
print(f'Semana 5 - Teste t HI vs. HM = {ttest_ind(S5_HI, S5_HM)}')
print(f'Semana 5 - Teste t HI vs. HPM = {ttest_ind(S5_HI, S5_HPM)}')
print(f'Semana 5 - Teste t HP vs. HM = {ttest_ind(S5_HP, S5_HM)}')
print(f'Semana 5 - Teste t HP vs. HPM = {ttest_ind(S5_HI, S5_HPM)}')
print(f'Semana 5 - Teste t HM vs. HPM = {ttest_ind(S5_HI, S5_HPM)}')

print((140*"_"))

#|Semana 6|
sem6_P = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="AC:AG", skiprows=8, nrows=1)
S6_P = np.transpose(sem6_P)
sem6_PP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="AC:AG", skiprows=20, nrows=1)
S6_PP = np.transpose(sem6_PP)
sem6_HL = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="AC:AG", skiprows=32, nrows=1)
S6_HL = np.transpose(sem6_HL)
sem6_HI = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="AC:AG", skiprows=44, nrows=1)
S6_HI = np.transpose(sem6_HI)
sem6_HP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="AC:AG", skiprows=56, nrows=1)
S6_HP = np.transpose(sem6_HP)
sem6_HM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="AC:AG", skiprows=68, nrows=1)
S6_HM = np.transpose(sem6_HM)
sem6_HPM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="AC:AG", skiprows=80, nrows=1)
S6_HPM = np.transpose(sem6_HPM)

print(f'Semana 6 - Teste t P vs. PP = {ttest_ind(S6_P, S6_PP)}')
print(f'Semana 6 - Teste t P vs. HL = {ttest_ind(S6_P, S6_HL)}')
print(f'Semana 6 - Teste t P vs. HI = {ttest_ind(S6_P, S6_HI)}')
print(f'Semana 6 - Teste t P vs. HP = {ttest_ind(S6_P, S6_HP)}')
print(f'Semana 6 - Teste t P vs. HM = {ttest_ind(S6_P, S6_HM)}')
print(f'Semana 6 - Teste t P vs. HPM = {ttest_ind(S6_P, S6_HPM)}')
print(f'Semana 6 - Teste t PP vs. HL = {ttest_ind(S6_PP, S6_HL)}')
print(f'Semana 6 - Teste t PP vs. HI = {ttest_ind(S6_PP, S6_HI)}')
print(f'Semana 6 - Teste t PP vs. HP = {ttest_ind(S6_PP, S6_HP)}')
print(f'Semana 6 - Teste t PP vs. HM = {ttest_ind(S6_PP, S6_HM)}')
print(f'Semana 6 - Teste t PP vs. HPM = {ttest_ind(S6_PP, S6_HPM)}')
print(f'Semana 6 - Teste t HL vs. HI = {ttest_ind(S6_HL, S6_HI)}')
print(f'Semana 6 - Teste t HL vs. HP = {ttest_ind(S6_HL, S6_HP)}')
print(f'Semana 6 - Teste t HL vs. HM = {ttest_ind(S6_HL, S6_HM)}')
print(f'Semana 6 - Teste t HL vs. HPM = {ttest_ind(S6_HL, S6_HPM)}')
print(f'Semana 6 - Teste t HI vs. HP = {ttest_ind(S6_HI, S6_HP)}')
print(f'Semana 6 - Teste t HI vs. HM = {ttest_ind(S6_HI, S6_HM)}')
print(f'Semana 6 - Teste t HI vs. HPM = {ttest_ind(S6_HI, S6_HPM)}')
print(f'Semana 6 - Teste t HP vs. HM = {ttest_ind(S6_HP, S6_HM)}')
print(f'Semana 6 - Teste t HP vs. HPM = {ttest_ind(S6_HI, S6_HPM)}')
print(f'Semana 6 - Teste t HM vs. HPM = {ttest_ind(S6_HI, S6_HPM)}')

print((140*"_"))

#|Semana 7|
sem7_P = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="AH:AL", skiprows=8, nrows=1)
S7_P = np.transpose(sem7_P)
sem7_PP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="AH:AL", skiprows=20, nrows=1)
S7_PP = np.transpose(sem7_PP)
sem7_HL = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="AH:AL", skiprows=32, nrows=1)
S7_HL = np.transpose(sem7_HL)
sem7_HI = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="AH:AL", skiprows=44, nrows=1)
S7_HI = np.transpose(sem7_HI)
sem7_HP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="AH:AL", skiprows=56, nrows=1)
S7_HP = np.transpose(sem7_HP)
sem7_HM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="AH:AL", skiprows=68, nrows=1)
S7_HM = np.transpose(sem7_HM)
sem7_HPM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="AH:AL", skiprows=80, nrows=1)
S7_HPM = np.transpose(sem7_HPM)

print(f'Semana 7 - Teste t P vs. PP = {ttest_ind(S7_P, S7_PP)}')
print(f'Semana 7 - Teste t P vs. HL = {ttest_ind(S7_P, S7_HL)}')
print(f'Semana 7 - Teste t P vs. HI = {ttest_ind(S7_P, S7_HI)}')
print(f'Semana 7 - Teste t P vs. HP = {ttest_ind(S7_P, S7_HP)}')
print(f'Semana 7 - Teste t P vs. HM = {ttest_ind(S7_P, S7_HM)}')
print(f'Semana 7 - Teste t P vs. HPM = {ttest_ind(S7_P, S7_HPM)}')
print(f'Semana 7 - Teste t PP vs. HL = {ttest_ind(S7_PP, S7_HL)}')
print(f'Semana 7 - Teste t PP vs. HI = {ttest_ind(S7_PP, S7_HI)}')
print(f'Semana 7 - Teste t PP vs. HP = {ttest_ind(S7_PP, S7_HP)}')
print(f'Semana 7 - Teste t PP vs. HM = {ttest_ind(S7_PP, S7_HM)}')
print(f'Semana 7 - Teste t PP vs. HPM = {ttest_ind(S7_PP, S7_HPM)}')
print(f'Semana 7 - Teste t HL vs. HI = {ttest_ind(S7_HL, S7_HI)}')
print(f'Semana 7 - Teste t HL vs. HP = {ttest_ind(S7_HL, S7_HP)}')
print(f'Semana 7 - Teste t HL vs. HM = {ttest_ind(S7_HL, S7_HM)}')
print(f'Semana 7 - Teste t HL vs. HPM = {ttest_ind(S7_HL, S7_HPM)}')
print(f'Semana 7 - Teste t HI vs. HP = {ttest_ind(S7_HI, S7_HP)}')
print(f'Semana 7 - Teste t HI vs. HM = {ttest_ind(S7_HI, S7_HM)}')
print(f'Semana 7 - Teste t HI vs. HPM = {ttest_ind(S7_HI, S7_HPM)}')
print(f'Semana 7 - Teste t HP vs. HM = {ttest_ind(S7_HP, S7_HM)}')
print(f'Semana 7 - Teste t HP vs. HPM = {ttest_ind(S7_HI, S7_HPM)}')
print(f'Semana 7 - Teste t HM vs. HPM = {ttest_ind(S7_HI, S7_HPM)}')

print((140*"_"))

#|Semana 8|
sem8_P = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="AM:AQ", skiprows=8, nrows=1)
S8_P = np.transpose(sem8_P)
sem8_PP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="AM:AQ", skiprows=20, nrows=1)
S8_PP = np.transpose(sem8_PP)
sem8_HL = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="AM:AQ", skiprows=32, nrows=1)
S8_HL = np.transpose(sem8_HL)
sem8_HI = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="AM:AQ", skiprows=44, nrows=1)
S8_HI = np.transpose(sem8_HI)
sem8_HP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="AM:AQ", skiprows=56, nrows=1)
S8_HP = np.transpose(sem8_HP)
sem8_HM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="AM:AQ", skiprows=68, nrows=1)
S8_HM = np.transpose(sem8_HM)
sem8_HPM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="AM:AQ", skiprows=80, nrows=1)
S8_HPM = np.transpose(sem8_HPM)

print(f'Semana 8 - Teste t P vs. PP = {ttest_ind(S8_P, S8_PP)}')
print(f'Semana 8 - Teste t P vs. HL = {ttest_ind(S8_P, S8_HL)}')
print(f'Semana 8 - Teste t P vs. HI = {ttest_ind(S8_P, S8_HI)}')
print(f'Semana 8 - Teste t P vs. HP = {ttest_ind(S8_P, S8_HP)}')
print(f'Semana 8 - Teste t P vs. HM = {ttest_ind(S8_P, S8_HM)}')
print(f'Semana 8 - Teste t P vs. HPM = {ttest_ind(S8_P, S8_HPM)}')
print(f'Semana 8 - Teste t PP vs. HL = {ttest_ind(S8_PP, S8_HL)}')
print(f'Semana 8 - Teste t PP vs. HI = {ttest_ind(S8_PP, S8_HI)}')
print(f'Semana 8 - Teste t PP vs. HP = {ttest_ind(S8_PP, S8_HP)}')
print(f'Semana 8 - Teste t PP vs. HM = {ttest_ind(S8_PP, S8_HM)}')
print(f'Semana 8 - Teste t PP vs. HPM = {ttest_ind(S8_PP, S8_HPM)}')
print(f'Semana 8 - Teste t HL vs. HI = {ttest_ind(S8_HL, S8_HI)}')
print(f'Semana 8 - Teste t HL vs. HP = {ttest_ind(S8_HL, S8_HP)}')
print(f'Semana 8 - Teste t HL vs. HM = {ttest_ind(S8_HL, S8_HM)}')
print(f'Semana 8 - Teste t HL vs. HPM = {ttest_ind(S8_HL, S8_HPM)}')
print(f'Semana 8 - Teste t HI vs. HP = {ttest_ind(S8_HI, S8_HP)}')
print(f'Semana 8 - Teste t HI vs. HM = {ttest_ind(S8_HI, S8_HM)}')
print(f'Semana 8 - Teste t HI vs. HPM = {ttest_ind(S8_HI, S8_HPM)}')
print(f'Semana 8 - Teste t HP vs. HM = {ttest_ind(S8_HP, S8_HM)}')
print(f'Semana 8 - Teste t HP vs. HPM = {ttest_ind(S8_HI, S8_HPM)}')
print(f'Semana 8 - Teste t HM vs. HPM = {ttest_ind(S8_HI, S8_HPM)}')

print((140*"_"))

#|Semana 9|
sem9_P = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="AR:AV", skiprows=8, nrows=1)
S9_P = np.transpose(sem9_P)
sem9_PP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="AR:AV", skiprows=20, nrows=1)
S9_PP = np.transpose(sem9_PP)
sem9_HL = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="AR:AV", skiprows=32, nrows=1)
S9_HL = np.transpose(sem9_HL)
sem9_HI = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="AR:AV", skiprows=44, nrows=1)
S9_HI = np.transpose(sem9_HI)
sem9_HP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="AR:AV", skiprows=56, nrows=1)
S9_HP = np.transpose(sem9_HP)
sem9_HM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="AR:AV", skiprows=68, nrows=1)
S9_HM = np.transpose(sem9_HM)
sem9_HPM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="AR:AV", skiprows=80, nrows=1)
S9_HPM = np.transpose(sem9_HPM)

print(f'Semana 9 - Teste t P vs. PP = {ttest_ind(S9_P, S9_PP)}')
print(f'Semana 9 - Teste t P vs. HL = {ttest_ind(S9_P, S9_HL)}')
print(f'Semana 9 - Teste t P vs. HI = {ttest_ind(S9_P, S9_HI)}')
print(f'Semana 9 - Teste t P vs. HP = {ttest_ind(S9_P, S9_HP)}')
print(f'Semana 9 - Teste t P vs. HM = {ttest_ind(S9_P, S9_HM)}')
print(f'Semana 9 - Teste t P vs. HPM = {ttest_ind(S9_P, S9_HPM)}')
print(f'Semana 9 - Teste t PP vs. HL = {ttest_ind(S9_PP, S9_HL)}')
print(f'Semana 9 - Teste t PP vs. HI = {ttest_ind(S9_PP, S9_HI)}')
print(f'Semana 9 - Teste t PP vs. HP = {ttest_ind(S9_PP, S9_HP)}')
print(f'Semana 9 - Teste t PP vs. HM = {ttest_ind(S9_PP, S9_HM)}')
print(f'Semana 9 - Teste t PP vs. HPM = {ttest_ind(S9_PP, S9_HPM)}')
print(f'Semana 9 - Teste t HL vs. HI = {ttest_ind(S9_HL, S9_HI)}')
print(f'Semana 9 - Teste t HL vs. HP = {ttest_ind(S9_HL, S9_HP)}')
print(f'Semana 9 - Teste t HL vs. HM = {ttest_ind(S9_HL, S9_HM)}')
print(f'Semana 9 - Teste t HL vs. HPM = {ttest_ind(S9_HL, S9_HPM)}')
print(f'Semana 9 - Teste t HI vs. HP = {ttest_ind(S9_HI, S9_HP)}')
print(f'Semana 9 - Teste t HI vs. HM = {ttest_ind(S9_HI, S9_HM)}')
print(f'Semana 9 - Teste t HI vs. HPM = {ttest_ind(S9_HI, S9_HPM)}')
print(f'Semana 9 - Teste t HP vs. HM = {ttest_ind(S9_HP, S9_HM)}')
print(f'Semana 9 - Teste t HP vs. HPM = {ttest_ind(S9_HI, S9_HPM)}')
print(f'Semana 9 - Teste t HM vs. HPM = {ttest_ind(S9_HI, S9_HPM)}')

print((140*"_"))

#|Semana 10|
sem10_P = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="AW:BA", skiprows=8, nrows=1)
S10_P = np.transpose(sem10_P)
sem10_PP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="AW:BA", skiprows=20, nrows=1)
S10_PP = np.transpose(sem10_PP)
sem10_HL = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="AW:BA", skiprows=32, nrows=1)
S10_HL = np.transpose(sem10_HL)
sem10_HI = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="AW:BA", skiprows=44, nrows=1)
S10_HI = np.transpose(sem10_HI)
sem10_HP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="AW:BA", skiprows=56, nrows=1)
S10_HP = np.transpose(sem10_HP)
sem10_HM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="AW:BA", skiprows=68, nrows=1)
S10_HM = np.transpose(sem10_HM)
sem10_HPM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="AW:BA", skiprows=80, nrows=1)
S10_HPM = np.transpose(sem10_HPM)

print(f'Semana 10 - Teste t P vs. PP = {ttest_ind(S10_P, S10_PP)}')
print(f'Semana 10 - Teste t P vs. HL = {ttest_ind(S10_P, S10_HL)}')
print(f'Semana 10 - Teste t P vs. HI = {ttest_ind(S10_P, S10_HI)}')
print(f'Semana 10 - Teste t P vs. HP = {ttest_ind(S10_P, S10_HP)}')
print(f'Semana 10 - Teste t P vs. HM = {ttest_ind(S10_P, S10_HM)}')
print(f'Semana 10 - Teste t P vs. HPM = {ttest_ind(S10_P, S10_HPM)}')
print(f'Semana 10 - Teste t PP vs. HL = {ttest_ind(S10_PP, S10_HL)}')
print(f'Semana 10 - Teste t PP vs. HI = {ttest_ind(S10_PP, S10_HI)}')
print(f'Semana 10 - Teste t PP vs. HP = {ttest_ind(S10_PP, S10_HP)}')
print(f'Semana 10 - Teste t PP vs. HM = {ttest_ind(S10_PP, S10_HM)}')
print(f'Semana 10 - Teste t PP vs. HPM = {ttest_ind(S10_PP, S10_HPM)}')
print(f'Semana 10 - Teste t HL vs. HI = {ttest_ind(S10_HL, S10_HI)}')
print(f'Semana 10 - Teste t HL vs. HP = {ttest_ind(S10_HL, S10_HP)}')
print(f'Semana 10 - Teste t HL vs. HM = {ttest_ind(S10_HL, S10_HM)}')
print(f'Semana 10 - Teste t HL vs. HPM = {ttest_ind(S10_HL, S10_HPM)}')
print(f'Semana 10 - Teste t HI vs. HP = {ttest_ind(S10_HI, S10_HP)}')
print(f'Semana 10 - Teste t HI vs. HM = {ttest_ind(S10_HI, S10_HM)}')
print(f'Semana 10 - Teste t HI vs. HPM = {ttest_ind(S10_HI, S10_HPM)}')
print(f'Semana 10 - Teste t HP vs. HM = {ttest_ind(S10_HP, S10_HM)}')
print(f'Semana 10 - Teste t HP vs. HPM = {ttest_ind(S10_HI, S10_HPM)}')
print(f'Semana 10 - Teste t HM vs. HPM = {ttest_ind(S10_HI, S10_HPM)}')

print((140*"_"))

#|Semana 11|
sem11_P = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="BB:BF", skiprows=8, nrows=1)
S11_P = np.transpose(sem11_P)
sem11_PP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="BB:BF", skiprows=20, nrows=1)
S11_PP = np.transpose(sem11_PP)
sem11_HL = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="BB:BF", skiprows=32, nrows=1)
S11_HL = np.transpose(sem11_HL)
sem11_HI = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="BB:BF", skiprows=44, nrows=1)
S11_HI = np.transpose(sem11_HI)
sem11_HP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="BB:BF", skiprows=56, nrows=1)
S11_HP = np.transpose(sem11_HP)
sem11_HM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="BB:BF", skiprows=68, nrows=1)
S11_HM = np.transpose(sem11_HM)
sem11_HPM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="BB:BF", skiprows=80, nrows=1)
S11_HPM = np.transpose(sem11_HPM)

print(f'Semana 11 - Teste t P vs. PP = {ttest_ind(S11_P, S11_PP)}')
print(f'Semana 11 - Teste t P vs. HL = {ttest_ind(S11_P, S11_HL)}')
print(f'Semana 11 - Teste t P vs. HI = {ttest_ind(S11_P, S11_HI)}')
print(f'Semana 11 - Teste t P vs. HP = {ttest_ind(S11_P, S11_HP)}')
print(f'Semana 11 - Teste t P vs. HM = {ttest_ind(S11_P, S11_HM)}')
print(f'Semana 11 - Teste t P vs. HPM = {ttest_ind(S11_P, S11_HPM)}')
print(f'Semana 11 - Teste t PP vs. HL = {ttest_ind(S11_PP, S11_HL)}')
print(f'Semana 11 - Teste t PP vs. HI = {ttest_ind(S11_PP, S11_HI)}')
print(f'Semana 11 - Teste t PP vs. HP = {ttest_ind(S11_PP, S11_HP)}')
print(f'Semana 11 - Teste t PP vs. HM = {ttest_ind(S11_PP, S11_HM)}')
print(f'Semana 11 - Teste t PP vs. HPM = {ttest_ind(S11_PP, S11_HPM)}')
print(f'Semana 11 - Teste t HL vs. HI = {ttest_ind(S11_HL, S11_HI)}')
print(f'Semana 11 - Teste t HL vs. HP = {ttest_ind(S11_HL, S11_HP)}')
print(f'Semana 11 - Teste t HL vs. HM = {ttest_ind(S11_HL, S11_HM)}')
print(f'Semana 11 - Teste t HL vs. HPM = {ttest_ind(S11_HL, S11_HPM)}')
print(f'Semana 11 - Teste t HI vs. HP = {ttest_ind(S11_HI, S11_HP)}')
print(f'Semana 11 - Teste t HI vs. HM = {ttest_ind(S11_HI, S11_HM)}')
print(f'Semana 11 - Teste t HI vs. HPM = {ttest_ind(S11_HI, S11_HPM)}')
print(f'Semana 11 - Teste t HP vs. HM = {ttest_ind(S11_HP, S11_HM)}')
print(f'Semana 11 - Teste t HP vs. HPM = {ttest_ind(S11_HI, S11_HPM)}')
print(f'Semana 11 - Teste t HM vs. HPM = {ttest_ind(S11_HI, S11_HPM)}')

print((140*"_"))

#|Semana 12|
sem12_P = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="BG:BK", skiprows=8, nrows=1)
S12_P = np.transpose(sem12_P)
sem12_PP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="BG:BK", skiprows=20, nrows=1)
S12_PP = np.transpose(sem12_PP)
sem12_HL = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="BG:BK", skiprows=32, nrows=1)
S12_HL = np.transpose(sem12_HL)
sem12_HI = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="BG:BK", skiprows=44, nrows=1)
S12_HI = np.transpose(sem12_HI)
sem12_HP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="BG:BK", skiprows=56, nrows=1)
S12_HP = np.transpose(sem12_HP)
sem12_HM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="BG:BK", skiprows=68, nrows=1)
S12_HM = np.transpose(sem12_HM)
sem12_HPM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="BG:BK", skiprows=80, nrows=1)
S12_HPM = np.transpose(sem12_HPM)

print(f'Semana 12 - Teste t P vs. PP = {ttest_ind(S12_P, S12_PP)}')
print(f'Semana 12 - Teste t P vs. HL = {ttest_ind(S12_P, S12_HL)}')
print(f'Semana 12 - Teste t P vs. HI = {ttest_ind(S12_P, S12_HI)}')
print(f'Semana 12 - Teste t P vs. HP = {ttest_ind(S12_P, S12_HP)}')
print(f'Semana 12 - Teste t P vs. HM = {ttest_ind(S12_P, S12_HM)}')
print(f'Semana 12 - Teste t P vs. HPM = {ttest_ind(S12_P, S12_HPM)}')
print(f'Semana 12 - Teste t PP vs. HL = {ttest_ind(S12_PP, S12_HL)}')
print(f'Semana 12 - Teste t PP vs. HI = {ttest_ind(S12_PP, S12_HI)}')
print(f'Semana 12 - Teste t PP vs. HP = {ttest_ind(S12_PP, S12_HP)}')
print(f'Semana 12 - Teste t PP vs. HM = {ttest_ind(S12_PP, S12_HM)}')
print(f'Semana 12 - Teste t PP vs. HPM = {ttest_ind(S12_PP, S12_HPM)}')
print(f'Semana 12 - Teste t HL vs. HI = {ttest_ind(S12_HL, S12_HI)}')
print(f'Semana 12 - Teste t HL vs. HP = {ttest_ind(S12_HL, S12_HP)}')
print(f'Semana 12 - Teste t HL vs. HM = {ttest_ind(S12_HL, S12_HM)}')
print(f'Semana 12 - Teste t HL vs. HPM = {ttest_ind(S12_HL, S12_HPM)}')
print(f'Semana 12 - Teste t HI vs. HP = {ttest_ind(S12_HI, S12_HP)}')
print(f'Semana 12 - Teste t HI vs. HM = {ttest_ind(S12_HI, S12_HM)}')
print(f'Semana 12 - Teste t HI vs. HPM = {ttest_ind(S12_HI, S12_HPM)}')
print(f'Semana 12 - Teste t HP vs. HM = {ttest_ind(S12_HP, S12_HM)}')
print(f'Semana 12 - Teste t HP vs. HPM = {ttest_ind(S12_HI, S12_HPM)}')
print(f'Semana 12 - Teste t HM vs. HPM = {ttest_ind(S12_HI, S12_HPM)}')

print((140*"_"))

#|Semana 13|
sem13_P = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="BL:BP", skiprows=8, nrows=1)
S13_P = np.transpose(sem13_P)
sem13_PP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="BL:BP", skiprows=20, nrows=1)
S13_PP = np.transpose(sem13_PP)
sem13_HL = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="BL:BP", skiprows=32, nrows=1)
S13_HL = np.transpose(sem13_HL)
sem13_HI = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="BL:BP", skiprows=44, nrows=1)
S13_HI = np.transpose(sem13_HI)
sem13_HP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="BL:BP", skiprows=56, nrows=1)
S13_HP = np.transpose(sem13_HP)
sem13_HM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="BL:BP", skiprows=68, nrows=1)
S13_HM = np.transpose(sem13_HM)
sem13_HPM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="BL:BP", skiprows=80, nrows=1)
S13_HPM = np.transpose(sem13_HPM)

print(f'Semana 13 - Teste t P vs. PP = {ttest_ind(S13_P, S13_PP)}')
print(f'Semana 13 - Teste t P vs. HL = {ttest_ind(S13_P, S13_HL)}')
print(f'Semana 13 - Teste t P vs. HI = {ttest_ind(S13_P, S13_HI)}')
print(f'Semana 13 - Teste t P vs. HP = {ttest_ind(S13_P, S13_HP)}')
print(f'Semana 13 - Teste t P vs. HM = {ttest_ind(S13_P, S13_HM)}')
print(f'Semana 13 - Teste t P vs. HPM = {ttest_ind(S13_P, S13_HPM)}')
print(f'Semana 13 - Teste t PP vs. HL = {ttest_ind(S13_PP, S13_HL)}')
print(f'Semana 13 - Teste t PP vs. HI = {ttest_ind(S13_PP, S13_HI)}')
print(f'Semana 13 - Teste t PP vs. HP = {ttest_ind(S13_PP, S13_HP)}')
print(f'Semana 13 - Teste t PP vs. HM = {ttest_ind(S13_PP, S13_HM)}')
print(f'Semana 13 - Teste t PP vs. HPM = {ttest_ind(S13_PP, S13_HPM)}')
print(f'Semana 13 - Teste t HL vs. HI = {ttest_ind(S13_HL, S13_HI)}')
print(f'Semana 13 - Teste t HL vs. HP = {ttest_ind(S13_HL, S13_HP)}')
print(f'Semana 13 - Teste t HL vs. HM = {ttest_ind(S13_HL, S13_HM)}')
print(f'Semana 13 - Teste t HL vs. HPM = {ttest_ind(S13_HL, S13_HPM)}')
print(f'Semana 13 - Teste t HI vs. HP = {ttest_ind(S13_HI, S13_HP)}')
print(f'Semana 13 - Teste t HI vs. HM = {ttest_ind(S13_HI, S13_HM)}')
print(f'Semana 13 - Teste t HI vs. HPM = {ttest_ind(S13_HI, S13_HPM)}')
print(f'Semana 13 - Teste t HP vs. HM = {ttest_ind(S13_HP, S13_HM)}')
print(f'Semana 13 - Teste t HP vs. HPM = {ttest_ind(S13_HI, S13_HPM)}')
print(f'Semana 13 - Teste t HM vs. HPM = {ttest_ind(S13_HI, S13_HPM)}')

print((140*"_"))

#|Semana 14|
sem14_P = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="BQ:BU", skiprows=8, nrows=1)
S14_P = np.transpose(sem14_P)
sem14_PP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="BQ:BU", skiprows=20, nrows=1)
S14_PP = np.transpose(sem14_PP)
sem14_HL = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="BQ:BU", skiprows=32, nrows=1)
S14_HL = np.transpose(sem14_HL)
sem14_HI = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="BQ:BU", skiprows=44, nrows=1)
S14_HI = np.transpose(sem14_HI)
sem14_HP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="BQ:BU", skiprows=56, nrows=1)
S14_HP = np.transpose(sem14_HP)
sem14_HM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="BQ:BU", skiprows=68, nrows=1)
S14_HM = np.transpose(sem14_HM)
sem14_HPM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="BQ:BU", skiprows=80, nrows=1)
S14_HPM = np.transpose(sem14_HPM)

print(f'Semana 14 - Teste t P vs. PP = {ttest_ind(S14_P, S14_PP)}')
print(f'Semana 14 - Teste t P vs. HL = {ttest_ind(S14_P, S14_HL)}')
print(f'Semana 14 - Teste t P vs. HI = {ttest_ind(S14_P, S14_HI)}')
print(f'Semana 14 - Teste t P vs. HP = {ttest_ind(S14_P, S14_HP)}')
print(f'Semana 14 - Teste t P vs. HM = {ttest_ind(S14_P, S14_HM)}')
print(f'Semana 14 - Teste t P vs. HPM = {ttest_ind(S14_P, S14_HPM)}')
print(f'Semana 14 - Teste t PP vs. HL = {ttest_ind(S14_PP, S14_HL)}')
print(f'Semana 14 - Teste t PP vs. HI = {ttest_ind(S14_PP, S14_HI)}')
print(f'Semana 14 - Teste t PP vs. HP = {ttest_ind(S14_PP, S14_HP)}')
print(f'Semana 14 - Teste t PP vs. HM = {ttest_ind(S14_PP, S14_HM)}')
print(f'Semana 14 - Teste t PP vs. HPM = {ttest_ind(S14_PP, S14_HPM)}')
print(f'Semana 14 - Teste t HL vs. HI = {ttest_ind(S14_HL, S14_HI)}')
print(f'Semana 14 - Teste t HL vs. HP = {ttest_ind(S14_HL, S14_HP)}')
print(f'Semana 14 - Teste t HL vs. HM = {ttest_ind(S14_HL, S14_HM)}')
print(f'Semana 14 - Teste t HL vs. HPM = {ttest_ind(S14_HL, S14_HPM)}')
print(f'Semana 14 - Teste t HI vs. HP = {ttest_ind(S14_HI, S14_HP)}')
print(f'Semana 14 - Teste t HI vs. HM = {ttest_ind(S14_HI, S14_HM)}')
print(f'Semana 14 - Teste t HI vs. HPM = {ttest_ind(S14_HI, S14_HPM)}')
print(f'Semana 14 - Teste t HP vs. HM = {ttest_ind(S14_HP, S14_HM)}')
print(f'Semana 14 - Teste t HP vs. HPM = {ttest_ind(S14_HI, S14_HPM)}')
print(f'Semana 14 - Teste t HM vs. HPM = {ttest_ind(S14_HI, S14_HPM)}')

print((140*"_"))

#|Semana 15|
sem15_P = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="BV:BZ", skiprows=8, nrows=1)
S15_P = np.transpose(sem15_P)
sem15_PP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="BV:BZ", skiprows=20, nrows=1)
S15_PP = np.transpose(sem15_PP)
sem15_HL = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="BV:BZ", skiprows=32, nrows=1)
S15_HL = np.transpose(sem15_HL)
sem15_HI = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="BV:BZ", skiprows=44, nrows=1)
S15_HI = np.transpose(sem15_HI)
sem15_HP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="BV:BZ", skiprows=56, nrows=1)
S15_HP = np.transpose(sem15_HP)
sem15_HM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="BV:BZ", skiprows=68, nrows=1)
S15_HM = np.transpose(sem15_HM)
sem15_HPM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="BV:BZ", skiprows=80, nrows=1)
S15_HPM = np.transpose(sem15_HPM)

print(f'Semana 15 - Teste t P vs. PP = {ttest_ind(S15_P, S15_PP)}')
print(f'Semana 15 - Teste t P vs. HL = {ttest_ind(S15_P, S15_HL)}')
print(f'Semana 15 - Teste t P vs. HI = {ttest_ind(S15_P, S15_HI)}')
print(f'Semana 15 - Teste t P vs. HP = {ttest_ind(S15_P, S15_HP)}')
print(f'Semana 15 - Teste t P vs. HM = {ttest_ind(S15_P, S15_HM)}')
print(f'Semana 15 - Teste t P vs. HPM = {ttest_ind(S15_P, S15_HPM)}')
print(f'Semana 15 - Teste t PP vs. HL = {ttest_ind(S15_PP, S15_HL)}')
print(f'Semana 15 - Teste t PP vs. HI = {ttest_ind(S15_PP, S15_HI)}')
print(f'Semana 15 - Teste t PP vs. HP = {ttest_ind(S15_PP, S15_HP)}')
print(f'Semana 15 - Teste t PP vs. HM = {ttest_ind(S15_PP, S15_HM)}')
print(f'Semana 15 - Teste t PP vs. HPM = {ttest_ind(S15_PP, S15_HPM)}')
print(f'Semana 15 - Teste t HL vs. HI = {ttest_ind(S15_HL, S15_HI)}')
print(f'Semana 15 - Teste t HL vs. HP = {ttest_ind(S15_HL, S15_HP)}')
print(f'Semana 15 - Teste t HL vs. HM = {ttest_ind(S15_HL, S15_HM)}')
print(f'Semana 15 - Teste t HL vs. HPM = {ttest_ind(S15_HL, S15_HPM)}')
print(f'Semana 15 - Teste t HI vs. HP = {ttest_ind(S15_HI, S15_HP)}')
print(f'Semana 15 - Teste t HI vs. HM = {ttest_ind(S15_HI, S15_HM)}')
print(f'Semana 15 - Teste t HI vs. HPM = {ttest_ind(S15_HI, S15_HPM)}')
print(f'Semana 15 - Teste t HP vs. HM = {ttest_ind(S15_HP, S15_HM)}')
print(f'Semana 15 - Teste t HP vs. HPM = {ttest_ind(S15_HI, S15_HPM)}')
print(f'Semana 15 - Teste t HM vs. HPM = {ttest_ind(S15_HI, S15_HPM)}')

print((140*"_"))

#|Semana 16|
sem16_P = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="CA:CE", skiprows=8, nrows=1)
S16_P = np.transpose(sem16_P)
sem16_PP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="CA:CE", skiprows=20, nrows=1)
S16_PP = np.transpose(sem16_PP)
sem16_HL = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="CA:CE", skiprows=32, nrows=1)
S16_HL = np.transpose(sem16_HL)
sem16_HI = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="CA:CE", skiprows=44, nrows=1)
S16_HI = np.transpose(sem16_HI)
sem16_HP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="CA:CE", skiprows=56, nrows=1)
S16_HP = np.transpose(sem16_HP)
sem16_HM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="CA:CE", skiprows=68, nrows=1)
S16_HM = np.transpose(sem16_HM)
sem16_HPM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="CA:CE", skiprows=80, nrows=1)
S16_HPM = np.transpose(sem16_HPM)

print(f'Semana 16 - Teste t P vs. PP = {ttest_ind(S16_P, S16_PP)}')
print(f'Semana 15 - Teste t P vs. HL = {ttest_ind(S16_P, S16_HL)}')
print(f'Semana 15 - Teste t P vs. HI = {ttest_ind(S16_P, S16_HI)}')
print(f'Semana 16 - Teste t P vs. HP = {ttest_ind(S15_P, S16_HP)}')
print(f'Semana 16 - Teste t P vs. HM = {ttest_ind(S16_P, S16_HM)}')
print(f'Semana 16 - Teste t P vs. HPM = {ttest_ind(S16_P, S16_HPM)}')
print(f'Semana 16 - Teste t PP vs. HL = {ttest_ind(S16_PP, S16_HL)}')
print(f'Semana 16 - Teste t PP vs. HI = {ttest_ind(S16_PP, S16_HI)}')
print(f'Semana 16 - Teste t PP vs. HP = {ttest_ind(S16_PP, S16_HP)}')
print(f'Semana 16 - Teste t PP vs. HM = {ttest_ind(S16_PP, S16_HM)}')
print(f'Semana 16 - Teste t PP vs. HPM = {ttest_ind(S16_PP, S16_HPM)}')
print(f'Semana 16 - Teste t HL vs. HI = {ttest_ind(S16_HL, S16_HI)}')
print(f'Semana 16 - Teste t HL vs. HP = {ttest_ind(S16_HL, S16_HP)}')
print(f'Semana 16 - Teste t HL vs. HM = {ttest_ind(S16_HL, S16_HM)}')
print(f'Semana 16 - Teste t HL vs. HPM = {ttest_ind(S16_HL, S16_HPM)}')
print(f'Semana 16 - Teste t HI vs. HP = {ttest_ind(S16_HI, S16_HP)}')
print(f'Semana 16 - Teste t HI vs. HM = {ttest_ind(S16_HI, S16_HM)}')
print(f'Semana 16 - Teste t HI vs. HPM = {ttest_ind(S16_HI, S16_HPM)}')
print(f'Semana 16 - Teste t HP vs. HM = {ttest_ind(S16_HP, S16_HM)}')
print(f'Semana 16 - Teste t HP vs. HPM = {ttest_ind(S16_HI, S16_HPM)}')
print(f'Semana 16 - Teste t HM vs. HPM = {ttest_ind(S16_HI, S16_HPM)}')

# %% [markdown]
# ###**3.2. Código para construção de modelos de gráficos de ganho de peso e ingestão alimentar semanais de camundongos**

# %% [markdown]
# ####Através do uso das bibliotecas Pandas, Matplotlib e NumPy, além dos achados no item 3.1, abaixo constam as linhas de código que configuram a construção de gráficos de pontos e linhas associados aos dados de ganho de peso e ingestão alimentar semanais dos camundongos sujeitos às condições de estudo implementadas, os quais estão presentes em planilhas do arquivo "*Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx*".

# %%
#Importação de bibliotecas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#Importação de dados excel - Ganho de Peso Semanal
peso = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="V:AC", skiprows=2, nrows=17)
Peso = peso.values

#Variável x - Ganho de Peso Semanal
semana1 = [item[0] for item in Peso]

#Variáveis y - Ganho de Peso Semanal
PesoP = [item[1] for item in Peso]
PesoPP = [item[2] for item in Peso]
PesoHL = [item[3] for item in Peso]
PesoHI = [item[4] for item in Peso]
PesoHP = [item[5] for item in Peso]
PesoHM = [item[6] for item in Peso]
PesoHPM = [item[7] for item in Peso]

#Erro padrão - Ganho de Peso Semanl
erPesoP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="D:T", skiprows=17, nrows=1)
Erro_PesoP = erPesoP.values
erPesoPP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="D:T", skiprows=36, nrows=1)
Erro_PesoPP = erPesoPP.values
erPesoHL = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="D:T", skiprows=55, nrows=1)
Erro_PesoHL = erPesoHL.values
erPesoHI = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="D:T", skiprows=74, nrows=1)
Erro_PesoHI = erPesoHI.values
erPesoHP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="D:T", skiprows=93, nrows=1)
Erro_PesoHP = erPesoHP.values
erPesoHM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="D:T", skiprows=112, nrows=1)
Erro_PesoHM = erPesoHM.values
erPesoHPM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ganho de Peso", usecols="D:T", skiprows=132, nrows=1)
Erro_PesoHPM = erPesoHPM.values

#Tipo/formato do gráfico - Ganho de Peso Semanal
plt.figure(figsize=(6,8), edgecolor='k')
plt.subplot(211)
plt.plot(semana1, PesoP, 'k', linewidth=1)
plt.errorbar(semana1, PesoP, yerr=Erro_PesoP, fmt='o', markerfacecolor='w', markersize=6, ecolor='k', elinewidth=1, capsize=2, markeredgecolor='k', markeredgewidth=1, label="Padrão")
plt.plot(semana1, PesoPP, 'orange', linewidth=1)
plt.errorbar(semana1, PesoPP, yerr=Erro_PesoPP, fmt='p', markerfacecolor='orange', markersize=6, ecolor='orange', elinewidth=1, capsize=2, markeredgecolor='k', markeredgewidth=1, label="Padrão + Própolis")
plt.plot(semana1, PesoHL, 'r', linewidth=1)
plt.errorbar(semana1, PesoHL, yerr=Erro_PesoHL, fmt='^', markerfacecolor='r', markersize=6, ecolor='r', elinewidth=1, capsize=2, markeredgecolor='k', markeredgewidth=1, label="Hiperlipidico")
plt.plot(semana1, PesoHI, 'lightseagreen', linewidth=1)
plt.errorbar(semana1, PesoHI, yerr=Erro_PesoHI, fmt='d', markerfacecolor='lightseagreen', markersize=6, ecolor='lightseagreen', elinewidth=1, capsize=2, markeredgecolor='k', markeredgewidth=1, label="Hiperlipidico + Iorgute")
plt.plot(semana1, PesoHP, 'y', linewidth=1)
plt.errorbar(semana1, PesoHP, yerr=Erro_PesoHP, fmt='v', markerfacecolor='y', markersize=6, ecolor='y', elinewidth=1, capsize=2, markeredgecolor='k', markeredgewidth=1, label="Hiperlipidico + Própolis")
plt.plot(semana1, PesoHM, 'b', linewidth=1)
plt.errorbar(semana1, PesoHM, yerr=Erro_PesoHM, fmt='s', markerfacecolor='b', markersize=6, ecolor='b', elinewidth=1, capsize=2, markeredgecolor='k', markeredgewidth=1, label="Hiperlipídico + Metformina")
plt.plot(semana1, PesoHPM, 'purple', linewidth=1)
plt.errorbar(semana1, PesoHPM, yerr=Erro_PesoHPM, fmt='D', markerfacecolor='purple', markersize=6, ecolor='purple', elinewidth=1, capsize=2, markeredgecolor='k', markeredgewidth=1, label="Hiperlipídico + Própolis + Metformina")

#Comparações estatísticas entre grupos - Ganho de Peso Semanal
plt.text(0.35, 39.5, "P, PP vs. HL (p<0.05): Semana 3 a 16", fontsize=6.8, fontweight='bold')
plt.text(0.35, 38, "HP, HM vs. HL (p<0.05): Semana 9 a 16", fontsize=6.8, fontweight='bold')
plt.text(0.35, 36.5, "HPM vs. HL (p<0.05): Semana 16", fontsize=6.8, fontweight='bold')

#Configurações da linha vertical indicando momento de transição (início dos tratamentos) - Ganho de Peso Semanal
plt.axvline(x=8.5, color='k', linestyle=':', linewidth=1.5)

#Configurações do eixo x - Ganho de Peso Semanal
plt.xlabel("Semanas", labelpad=9, fontsize=11, fontweight='bold')
plt.xticks(fontsize=10, fontweight='bold')
plt.xticks(np.arange(0,18))
plt.xlim(0,17)

#Configurações do eixo y - Ganho de Peso Semanal
plt.ylabel("Peso corporal (g)", labelpad=11, fontsize=11, fontweight='bold')
plt.yticks(fontsize=10, fontweight='bold')
plt.ylim(22,40)

#Formatação complemento do gráfico - Ganho de Peso Semanal
plt.title("Ganho de peso semanal", pad=20, fontsize=14.5, fontstyle='italic', fontweight='bold', va='bottom')
plt.text(3.55, 41.8, 27*"_", fontsize=14.5, fontstyle='italic', fontweight='bold')
plt.tick_params(which='major', length=5, width=1.5)
plt.rcParams['axes.linewidth'] = 1.5
plt.rcParams['axes.spines.right'] = False
plt.rcParams['axes.spines.top'] = False

#----------------------------------------------------------

#Importação dados excel - Ingestão Alimentar Semanal
ingali = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="D:K", skiprows=87, nrows=17)
IngAli = ingali.values

#Variável x - Ingestão Alimentar Semanal
semana2 = [item[0] for item in IngAli]

#Variáveis y - Ingestão Alimentar Semanal
IngAli_P = [item[1] for item in IngAli]
IngAli_PP = [item[2] for item in IngAli]
IngAli_HL = [item[3] for item in IngAli]
IngAli_HI = [item[4] for item in IngAli]
IngAli_HP = [item[5] for item in IngAli]
IngAli_HM = [item[6] for item in IngAli]
IngAli_HPM = [item[7] for item in IngAli]

#Erro padrão - Ingestão Alimentar Semanal
erIngAli_P = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="D:CE", skiprows=10, nrows=1)
verIngAli_P = erIngAli_P.values
Erro_IngAli_P = [verIngAli_P[0,0], verIngAli_P[0,5], verIngAli_P[0,10], verIngAli_P[0,15], verIngAli_P[0,20], verIngAli_P[0,25], verIngAli_P[0,30], verIngAli_P[0,35], verIngAli_P[0,40], verIngAli_P[0,45], verIngAli_P[0,50], verIngAli_P[0,55], verIngAli_P[0,60], verIngAli_P[0,65], verIngAli_P[0,70], verIngAli_P[0,75]]
erIngAli_PP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="D:CE", skiprows=22, nrows=1)
verIngAli_PP = erIngAli_PP.values
Erro_IngAli_PP = [verIngAli_PP[0,0], verIngAli_PP[0,5], verIngAli_PP[0,10], verIngAli_PP[0,15], verIngAli_PP[0,20], verIngAli_PP[0,25], verIngAli_PP[0,30], verIngAli_PP[0,35], verIngAli_PP[0,40], verIngAli_PP[0,45], verIngAli_PP[0,50], verIngAli_PP[0,55], verIngAli_PP[0,60], verIngAli_PP[0,65], verIngAli_PP[0,70], verIngAli_PP[0,75]]
erIngAli_HL = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="D:CE", skiprows=34, nrows=1)
verIngAli_HL = erIngAli_HL.values
Erro_IngAli_HL = [verIngAli_HL[0,0], verIngAli_HL[0,5], verIngAli_HL[0,10], verIngAli_HL[0,15], verIngAli_HL[0,20], verIngAli_HL[0,25], verIngAli_HL[0,30], verIngAli_HL[0,35], verIngAli_HL[0,40], verIngAli_HL[0,45], verIngAli_HL[0,50], verIngAli_HL[0,55], verIngAli_HL[0,60], verIngAli_HL[0,65], verIngAli_HL[0,70], verIngAli_HL[0,75]]
erIngAli_HI = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="D:CE", skiprows=46, nrows=1)
verIngAli_HI = erIngAli_HI.values
Erro_IngAli_HI = [verIngAli_HI[0,0], verIngAli_HI[0,5], verIngAli_HI[0,10], verIngAli_HI[0,15], verIngAli_HI[0,20], verIngAli_HI[0,25], verIngAli_HI[0,30], verIngAli_HI[0,35], verIngAli_HI[0,40], verIngAli_HI[0,45], verIngAli_HI[0,50], verIngAli_HI[0,55], verIngAli_HI[0,60], verIngAli_HI[0,65], verIngAli_HI[0,70], verIngAli_HI[0,75]]
erIngAli_HP = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="D:CE", skiprows=58, nrows=1)
verIngAli_HP = erIngAli_HP.values
Erro_IngAli_HP = [verIngAli_HP[0,0], verIngAli_HP[0,5], verIngAli_HP[0,10], verIngAli_HP[0,15], verIngAli_HP[0,20], verIngAli_HP[0,25], verIngAli_HP[0,30], verIngAli_HP[0,35], verIngAli_HP[0,40], verIngAli_HP[0,45], verIngAli_HP[0,50], verIngAli_HP[0,55], verIngAli_HP[0,60], verIngAli_HP[0,65], verIngAli_HP[0,70], verIngAli_HP[0,75]]
erIngAli_HM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="D:CE", skiprows=70, nrows=1)
verIngAli_HM = erIngAli_HM.values
Erro_IngAli_HM = [verIngAli_HM[0,0], verIngAli_HM[0,5], verIngAli_HM[0,10], verIngAli_HM[0,15], verIngAli_HM[0,20], verIngAli_HM[0,25], verIngAli_HM[0,30], verIngAli_HM[0,35], verIngAli_HM[0,40], verIngAli_HM[0,45], verIngAli_HM[0,50], verIngAli_HM[0,55], verIngAli_HM[0,60], verIngAli_HM[0,65], verIngAli_HM[0,70], verIngAli_HM[0,75]]
erIngAli_HPM = pd.read_excel("Python - Ganho de Peso e Ingestão Alimentar de Camundongos.xlsx", sheet_name="Ingestão Alimentar", usecols="D:CE", skiprows=82, nrows=1)
verIngAli_HPM = erIngAli_HPM.values
Erro_IngAli_HPM = [verIngAli_HPM[0,0], verIngAli_HPM[0,5], verIngAli_HPM[0,10], verIngAli_HPM[0,15], verIngAli_HPM[0,20], verIngAli_HPM[0,25], verIngAli_HPM[0,30], verIngAli_HPM[0,35], verIngAli_HPM[0,40], verIngAli_HPM[0,45], verIngAli_HPM[0,50], verIngAli_HPM[0,55], verIngAli_HPM[0,60], verIngAli_HPM[0,65], verIngAli_HPM[0,70], verIngAli_HPM[0,75]]

#Tipo/formato do gráfico - Ingestão Alimentar Semanal
plt.figure(figsize=(6,8), edgecolor='k')
plt.subplot(212)
plt.plot(semana2, IngAli_P, 'k', linewidth=1)
plt.errorbar(semana2, IngAli_P, yerr=Erro_IngAli_P, fmt='o', markerfacecolor='w', markersize=6, ecolor='k', elinewidth=1, capsize=2, markeredgecolor='k', markeredgewidth=1, label="Padrão (P)")
plt.plot(semana2, IngAli_PP, 'orange', linewidth=1)
plt.errorbar(semana2, IngAli_PP, yerr=Erro_IngAli_PP, fmt='p', markerfacecolor='orange', markersize=6, ecolor='orange', elinewidth=1, capsize=2, markeredgecolor='k', markeredgewidth=1, label="Padrão + Própolis (PP)")
plt.plot(semana2, IngAli_HL, 'r', linewidth=1)
plt.errorbar(semana2, IngAli_HL, yerr=Erro_IngAli_HL, fmt='^', markerfacecolor='r', markersize=6, ecolor='r', elinewidth=1, capsize=2, markeredgecolor='k', markeredgewidth=1, label="Hiperlipidico (HL)")
plt.plot(semana2, IngAli_HI, 'lightseagreen', linewidth=1)
plt.errorbar(semana2, IngAli_HI, yerr=Erro_IngAli_HI, fmt='d', markerfacecolor='lightseagreen', markersize=6, ecolor='lightseagreen', elinewidth=1, capsize=2, markeredgecolor='k', markeredgewidth=1, label="Hiperlipidico + Iorgute (HI)")
plt.plot(semana2, IngAli_HP, 'y', linewidth=1)
plt.errorbar(semana2, IngAli_HP, yerr=Erro_IngAli_HP, fmt='v', markerfacecolor='y', markersize=6, ecolor='y', elinewidth=1, capsize=2, markeredgecolor='k', markeredgewidth=1, label="Hiperlipidico + Própolis (HP)")
plt.plot(semana2, IngAli_HM, 'b', linewidth=1)
plt.errorbar(semana2, IngAli_HM, yerr=Erro_IngAli_HM, fmt='s', markerfacecolor='b', markersize=6, ecolor='b', elinewidth=1, capsize=2, markeredgecolor='k', markeredgewidth=1, label="Hiperlipídico + Metformina (HM)")
plt.plot(semana2, IngAli_HPM, 'purple', linewidth=1)
plt.errorbar(semana2, IngAli_HPM, yerr=Erro_IngAli_HPM, fmt='D', markerfacecolor='purple', markersize=6, ecolor='purple', elinewidth=1, capsize=2, markeredgecolor='k', markeredgewidth=1, label="Hiperlipídico + Própolis + Metformina (HPM)")

#Comparações estatísticas entre grupos - Ganho de Peso Semanal
plt.text(7.89, 3.45,"*", fontsize=10, fontweight='bold')
plt.axvline(x=7.7, ymin=0.685, ymax=0.975, color='k', linestyle='-', linewidth=1)
plt.axvline(x=8.3, ymin=0.685, ymax=0.975, color='k', linestyle='-', linewidth=1)
plt.axhline(y=3.45, xmin=0.42, xmax=0.456, color='k', linestyle='-', linewidth=1)
plt.axhline(y=2.705, xmin=0.42, xmax=0.456, color='k', linestyle='-', linewidth=1)
plt.text(10.05, 1.68,"*", fontsize=10, fontweight='bold')
plt.text(10.4, 1.7, "P vs. PP (p<0.05)", fontsize=6.8, fontweight='bold')
plt.text(10.4, 1.5, "P, PP vs. HL (p<0.05): Semana 1 a 16", fontsize=6.8, fontweight='bold')
plt.text(10.4, 1.3, "HP vs. HL (p<0.05): Semana 3 a 8", fontsize=6.8, fontweight='bold')


#Configurações da legenda - Ganho de Peso e Ingestão Alimentar Semanais
plt.legend(prop={'weight':'bold'}, fontsize=10.5, frameon=False, ncols= 2, loc='lower center',bbox_to_anchor=(0.62, -0.6))

#Configurações da linha vertical indicando momento de transição (início dos tratamentos) - Ingestão Alimentar Semanal
plt.axvline(x=8.5, color='k', linestyle=':', linewidth=1.5)

#Configurações do eixo x - Ingestão Alimentar Semanal
plt.xlabel("Semanas", labelpad=9, fontsize=11, fontweight='bold')
plt.xticks(fontsize=10, fontweight='bold')
plt.xticks(np.arange(0,18))
plt.xlim(1,17)

#Configurações do eixo y - Ingestão Alimentar Semanal
plt.ylabel("Ingestão alimentar (g/dia)", labelpad=11, fontsize=11, fontweight='bold')
plt.yticks(fontsize=10, fontweight='bold')
plt.ylim(1,3.5)

#Formatação complemento do gráfico - Ingestão Alimentar Semanal
plt.title(" ",  pad=25, fontsize=35)
plt.text(3.55, 3.82,"Ingestão alimentar semanal", fontsize=14.5, fontstyle='italic', fontweight='bold')
plt.text(3.55, 3.78, 31*"_", fontsize=14.5, fontstyle='italic', fontweight='bold')
plt.tick_params(which='major', length=5, width=1.5)
plt.rcParams['axes.linewidth'] = 1.5
plt.rcParams['axes.spines.right'] = False
plt.rcParams['axes.spines.top'] = False

plt.show()
